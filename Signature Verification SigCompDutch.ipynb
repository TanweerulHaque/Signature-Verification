# %%
import pandas as pd
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras import layers, initializers
from keras.layers import *
from keras.models import * 
from keras.utils import *
from keras.preprocessing import image
import tensorflow as tf
import random
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
from keras.models import load_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/sign_data_mod_mod.zip"
# Out:
# Archive:  /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/sign_data_mod_mod.zip
#    creating: sign_data_mod_mod/
#    creating: sign_data_mod_mod/test/
#    creating: sign_data_mod_mod/test/FORGED/
#  extracting: sign_data_mod_mod/test/FORGED/01_0101066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0102054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0102061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0104051.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0104059.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0104063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0105056.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0105064.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0106052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0106069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0107053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0108063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0108069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0109052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0109058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0109062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0110058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0111060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0111069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0112061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0113068.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0114049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0115053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0115056.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0116062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0117057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0118055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0118065.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0119063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0120051.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0120055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0121060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0124054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0124068.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0125050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0125058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0125059.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0126050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0126060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0127058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0127066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0201062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0202053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0202055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0203064.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0204050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0205067.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0206049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0206061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0206065.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0207052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0207053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0207054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0208054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0208057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0210049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0210052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0210057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0211066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0212066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0212067.PNG
#  extracting: sign_data_mod_mod/test/FORGED/01_0214054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0101066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0102054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0102061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0104051.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0104059.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0104063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0105056.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0105064.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0106052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0106069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0107053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0108063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0108069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0109052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0109058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0109062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0110058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0111060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0111069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0112061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0113068.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0114049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0115053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0115056.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0116062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0117057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0118055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0118065.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0119063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0120051.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0120055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0121060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0124054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0124068.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0125050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0125058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0125059.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0126050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0126060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0127058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0127066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0201062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0202053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0202055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0203064.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0204050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0205067.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0206049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0206061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0206065.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0207052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0207053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0207054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0208054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0208057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0210049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0210052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0210057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0211066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0212066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0212067.PNG
#  extracting: sign_data_mod_mod/test/FORGED/02_0214054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0101066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0102054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0102061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0104051.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0104059.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0104063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0105056.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0105064.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0106052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0106069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0107053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0108063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0108069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0109052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0109058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0109062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0110058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0111060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0111069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0112061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0113068.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0114049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0115053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0115056.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0116062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0117057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0118055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0118065.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0119063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0120051.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0120055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0121060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0124054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0124068.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0125050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0125058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0125059.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0126050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0126060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0127058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0127066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0201062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0202053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0202055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0203064.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0204050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0205067.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0206049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0206061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0206065.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0207052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0207053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0207054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0208054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0208057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0210049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0210052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0210057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0211066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0212066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0212067.PNG
#  extracting: sign_data_mod_mod/test/FORGED/03_0214054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0101066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0102054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0102061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0104051.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0104059.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0104063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0105056.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0105064.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0106052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0106069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0107053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0108063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0108069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0109052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0109058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0109062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0110058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0111060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0111069.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0112061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0113068.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0114049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0115053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0115056.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0116062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0117057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0118055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0118065.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0119063.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0120051.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0120055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0121060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0124054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0124068.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0125050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0125058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0125059.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0126050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0126060.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0127058.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0127066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0201062.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0202053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0202055.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0203064.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0204050.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0205067.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0206049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0206061.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0206065.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0207052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0207053.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0207054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0208054.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0208057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0210049.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0210052.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0210057.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0211066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0212066.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0212067.PNG
#  extracting: sign_data_mod_mod/test/FORGED/04_0214054.PNG
#    creating: sign_data_mod_mod/test/GENUINE/
#  extracting: sign_data_mod_mod/test/GENUINE/01_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/01_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/02_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/03_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/04_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/05_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_061.png
#   inflating: sign_data_mod_mod/test/GENUINE/06_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/06_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/07_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/08_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/09_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/10_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/11_069.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_049.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_050.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_051.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_052.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_053.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_054.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_055.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_056.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_057.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_058.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_059.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_060.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_061.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_062.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_063.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_064.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_065.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_066.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_067.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_068.png
#  extracting: sign_data_mod_mod/test/GENUINE/12_069.png
#   inflating: sign_data_mod_mod/test_data.csv
#    creating: sign_data_mod_mod/train/
#    creating: sign_data_mod_mod/train/FORGED/
#  extracting: sign_data_mod_mod/train/FORGED/0102014_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0102014_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0102014_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0102014_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0103004_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0103004_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0103004_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0104014_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0104014_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0104014_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0104014_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0105004_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0105004_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0105004_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0105004_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0106015_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0106015_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0106015_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0106015_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0107016_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0107016_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0107016_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0107016_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0108002_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0108002_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0108002_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0108002_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0110002_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0110002_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0110002_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0110002_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0110016_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0110016_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0110016_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0110016_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0111006_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0111006_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0111006_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0111006_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0113012_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0113012_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0113012_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0113012_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0117009_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0117009_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0117009_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0117009_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0118002_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0118002_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0118002_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0118002_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0119001_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0119001_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0119001_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0119001_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0121003_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0121003_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0121003_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0121003_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0123009_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0123009_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0123009_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0123009_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0124004_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0124004_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0124004_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0124004_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0126003_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0126003_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0126003_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0126003_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0127016_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0127016_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0127016_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0127016_04.png
#  extracting: sign_data_mod_mod/train/FORGED/01_0101027.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0101038.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0101066.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0102024.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0102039.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0102054.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0102061.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0103031.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0103034.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0103035.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0103044.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0104029.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0104051.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0104059.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0104063.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0105020.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0105041.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0105056.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0105064.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0106018.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0106048.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0106052.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0106069.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0107017.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0107042.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0107046.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0107053.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0108039.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0108046.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0108063.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0108069.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0109030.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0109036.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0109052.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0109058.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0109062.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0110021.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0110034.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0110058.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0111043.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0111045.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0111060.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0111069.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0112018.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0112032.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0112033.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0112044.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0112061.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0113013.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0113039.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0113047.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0113068.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0114030.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0114037.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0114040.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0114047.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0114049.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0115019.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0115029.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0115035.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0115053.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0115056.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0116019.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0116025.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0116041.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0116045.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0116062.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0117020.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0117032.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0117041.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0117057.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0118036.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0118042.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0118055.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0118065.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0119019.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0119024.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0119026.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0119063.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0120024.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0120032.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0120034.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0120051.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0120055.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0121025.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0121031.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0121040.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0121060.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0123026.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0123036.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0123037.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0123046.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0124017.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0124038.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0124054.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0124068.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0125022.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0125026.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0125050.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0125058.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0125059.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0126023.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0126028.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0126050.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0126060.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0127020.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0127022.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0127058.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0127066.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0201035.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0201043.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0201062.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0202018.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0202053.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0202055.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0203013.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0203023.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0203029.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0203033.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0203064.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0204013.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0204021.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0204042.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0204048.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0204050.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0205028.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0205033.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0205045.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0205067.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0206049.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0206061.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0206065.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0207052.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0207053.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0207054.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0208022.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0208037.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0208054.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0208057.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0210049.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0210052.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0210057.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0211017.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0211021.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0211043.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0211044.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0211066.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0212027.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0212028.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0212047.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0212066.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0212067.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0213020.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0213030.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0213033.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0213038.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0214022.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0214037.PNG
#  extracting: sign_data_mod_mod/train/FORGED/01_0214054.PNG
#  extracting: sign_data_mod_mod/train/FORGED/0201001_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0201001_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0201001_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0201001_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0201009_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0201009_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0201009_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0201009_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0202006_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0202006_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0202006_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0202006_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0202016_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0202016_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0202016_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0202016_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0205006_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0205006_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0205006_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0205006_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0206003_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0206003_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0206003_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0206003_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0206012_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0206012_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0206012_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0206012_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0208014_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0208014_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0208014_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0208014_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0210012_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0210012_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0210012_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0210012_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0210015_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0210015_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0210015_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0210015_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0213015_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0213015_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0213015_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0213015_04.png
#  extracting: sign_data_mod_mod/train/FORGED/0214014_01.png
#  extracting: sign_data_mod_mod/train/FORGED/0214014_02.png
#  extracting: sign_data_mod_mod/train/FORGED/0214014_03.png
#  extracting: sign_data_mod_mod/train/FORGED/0214014_04.png
#  extracting: sign_data_mod_mod/train/FORGED/02_0101020.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0101027.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0101038.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0101066.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0102024.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0102039.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0102054.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0102061.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0103031.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0103034.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0103035.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0103044.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0104029.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0104051.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0104059.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0104063.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0105020.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0105041.PNG
#  extracting: sign_data_mod_mod/train/FORGED/02_0105056.PNG
# ...
#  extracting: sign_data_mod_mod/train/GENUINE/07_065.png
#  extracting: sign_data_mod_mod/train/GENUINE/07_066.png
#  extracting: sign_data_mod_mod/train/GENUINE/07_067.png
#  extracting: sign_data_mod_mod/train/GENUINE/07_068.png
#  extracting: sign_data_mod_mod/train/GENUINE/07_069.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_013.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_017.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_018.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_019.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_020.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_021.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_022.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_023.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_024.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_025.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_026.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_027.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_028.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_029.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_030.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_031.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_032.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_033.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_034.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_035.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_036.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_037.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_038.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_039.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_040.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_041.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_042.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_043.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_044.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_045.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_046.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_047.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_048.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_049.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_050.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_051.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_052.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_053.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_054.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_055.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_056.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_057.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_058.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_059.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_060.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_061.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_062.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_063.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_064.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_065.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_066.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_067.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_068.png
#  extracting: sign_data_mod_mod/train/GENUINE/08_069.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_013.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_017.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_018.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_019.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_020.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_021.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_022.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_023.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_024.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_025.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_026.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_027.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_028.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_029.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_030.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_031.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_032.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_033.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_034.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_035.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_036.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_037.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_038.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_039.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_040.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_041.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_042.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_043.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_044.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_045.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_046.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_047.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_048.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_049.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_050.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_051.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_052.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_053.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_054.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_055.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_056.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_057.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_058.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_059.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_060.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_061.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_062.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_063.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_064.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_065.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_066.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_067.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_068.png
#  extracting: sign_data_mod_mod/train/GENUINE/09_069.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_013.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_017.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_018.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_019.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_020.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_021.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_022.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_023.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_024.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_025.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_026.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_027.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_028.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_029.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_030.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_031.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_032.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_033.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_034.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_035.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_036.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_037.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_038.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_039.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_040.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_041.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_042.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_043.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_044.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_045.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_046.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_047.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_048.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_049.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_050.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_051.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_052.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_053.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_054.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_055.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_056.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_057.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_058.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_059.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_060.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_061.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_062.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_063.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_064.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_065.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_066.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_067.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_068.png
#  extracting: sign_data_mod_mod/train/GENUINE/10_069.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_013.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_017.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_018.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_019.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_020.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_021.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_022.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_023.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_024.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_025.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_026.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_027.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_028.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_029.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_030.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_031.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_032.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_033.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_034.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_035.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_036.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_037.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_038.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_039.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_040.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_041.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_042.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_043.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_044.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_045.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_046.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_047.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_048.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_049.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_050.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_051.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_052.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_053.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_054.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_055.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_056.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_057.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_058.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_059.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_060.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_061.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_062.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_063.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_064.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_065.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_066.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_067.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_068.png
#  extracting: sign_data_mod_mod/train/GENUINE/11_069.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_013.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_017.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_018.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_019.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_020.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_021.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_022.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_023.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_024.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_025.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_026.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_027.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_028.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_029.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_030.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_031.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_032.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_033.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_034.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_035.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_036.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_037.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_038.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_039.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_040.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_041.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_042.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_043.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_044.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_045.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_046.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_047.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_048.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_049.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_050.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_051.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_052.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_053.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_054.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_055.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_056.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_057.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_058.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_059.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_060.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_061.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_062.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_063.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_064.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_065.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_066.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_067.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_068.png
#  extracting: sign_data_mod_mod/train/GENUINE/12_069.png
#   inflating: sign_data_mod_mod/train_data.csv

# %%
train_dir="/content/sign_data_mod_mod/train/"
train_csv="/content/sign_data_mod_mod/train_data.csv"
test_csv="/content/sign_data_mod_mod/test_data.csv"
test_dir="/content/sign_data_mod_mod/test/"

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import cv2

# %%
df_train = pd.read_csv(train_csv)
df_test = pd.read_csv(test_csv)

# %%
img = plt.imread(train_dir+"/"+(df_train.iat[1,0]))
plt.imshow(img)

# %%
img = plt.imread(train_dir+"/"+df_train.iat[1,1])
plt.imshow(img)

# %%
def Residual_Unit(input_tensor, nb_of_input_channels, max_dilation, number_of_units):
    
  for i in range(number_of_units):
    x1 = Conv2D(nb_of_input_channels*2, kernel_size = (1,1), strides = (1,1), padding='same', dilation_rate= (1,1), activation='relu')(input_tensor)
    x1 = BatchNormalization()(x1)
  
    a = []

    for i in range(1, max_dilation+1):
      temp = DepthwiseConv2D( kernel_size=(3,3), dilation_rate = (i,i), padding = 'same', activation= 'relu')(x1)
      temp = BatchNormalization()(temp)
      a.append(temp)

    x = Concatenate(axis= -1)(a)
    x = Conv2D(nb_of_input_channels, kernel_size = (1,1), strides = (1,1), padding='same', dilation_rate= (1,1), activation='relu')(x)
    x = BatchNormalization()(x)

    x = Add()([x, input_tensor])

    input_tensor = x
  
  return x

# %%
def Shifter_Unit(input_tensor, nb_of_input_channels, max_dilation):
    x1 = Conv2D(nb_of_input_channels*4, kernel_size = (1,1), strides = (1,1), padding='same', dilation_rate= (1,1), activation='relu')(input_tensor)
    x1 = BatchNormalization()(x1)

    a = []

    for i in range(1, max_dilation+1):
      temp = DepthwiseConv2D( kernel_size=(3,3), dilation_rate = (i,i), padding = 'same', activation= 'relu')(x1)
      temp = MaxPool2D(pool_size=(2,2))(temp)
      temp = BatchNormalization()(temp)
      a.append(temp)

    x = Concatenate(axis= -1)(a)

    x = Conv2D(nb_of_input_channels*2, kernel_size = (1,1), strides = (1,1), padding='same', dilation_rate= (1,1), activation='relu')(x)
    x = BatchNormalization()(x)

    return x

# %%
train_datagen = image.ImageDataGenerator(rescale = 1./255)
test_datagen = image.ImageDataGenerator(rescale= 1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (32,32),
    color_mode='grayscale',
    batch_size = 32,
    class_mode = "categorical"
    )
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (32,32),
    color_mode='grayscale',
    batch_size = 32,
    class_mode = "categorical"
    )
# Out:
# Found 1649 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'FORGED': 0, 'GENUINE': 1}

# %%
def Network32(input_shape, nb_class, depth):
  xin = Input(shape= input_shape)

  x = Conv2D(16, kernel_size = (5,5), strides= (1,1), padding = 'same', activation='relu')(xin)
  x = BatchNormalization()(x)

  x = Conv2D(32, kernel_size = (3,3), strides= (2,2), padding = 'same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=3, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=3)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=64, max_dilation=2, number_of_units=depth)

  x = GlobalAveragePooling2D()(x)

  x = Dense(64, activation='relu')(x)
  x = Dense(nb_class, activation= 'softmax')(x)

  model = Model(xin, x)

  model.compile(loss='categorical_crossentropy', optimizer = keras.optimizers.Adam(learning_rate=0.01), metrics = [tf.keras.metrics.AUC(),"accuracy"])

  return model

# %%
sig32_model = Network32(input_shape = (32, 32, 1), nb_class = 2 , depth = 5)
sig32_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   416         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 32)   4640        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 64)   2112        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 16, 16, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 16, 16, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 16, 16, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   256         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 192)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 32)   6176        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 32)   0           batch_normalization_6[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 64)   2112        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 16, 16, 64)   640         batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 16, 16, 64)   640         batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 16, 16, 64)   640         batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 192)  0           batch_normalization_8[0][0]
#                                                                  batch_normalization_9[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   6176        concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 32)   0           batch_normalization_11[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   2112        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 16, 16, 64)   640         batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 16, 16, 64)   640         batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 16, 16, 64)   640         batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 192)  0           batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 32)   6176        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 32)   0           batch_normalization_16[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   2112        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 16, 16, 64)   640         batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 16, 16, 64)   640         batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 16, 16, 64)   640         batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 192)  0           batch_normalization_18[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   6176        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 32)   0           batch_normalization_21[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   2112        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 16, 16, 64)   640         batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 16, 16, 64)   640         batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 16, 16, 64)   640         batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 64)   256         depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 192)  0           batch_normalization_23[0][0]
#                                                                  batch_normalization_24[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 32)   6176        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           batch_normalization_26[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  4224        add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 8, 8, 128)    0           depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 128)    0           depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)    0           depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 128)    512         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 128)    512         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 128)    512         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8, 8, 384)    0           batch_normalization_28[0][0]
#                                                                  batch_normalization_29[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 64)     24640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 64)     256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    8320        batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 128)    512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_18 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_19 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 8, 8, 256)    0           batch_normalization_33[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     16448       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 64)     0           batch_normalization_35[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 128)    8320        add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_21 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 8, 8, 256)    0           batch_normalization_37[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 64)     16448       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 64)     256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 64)     0           batch_normalization_39[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 128)    8320        add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 128)    512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_22 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 8, 8, 256)    0           batch_normalization_41[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     16448       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 8, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 64)     0           batch_normalization_43[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    8320        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8, 8, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_25 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 8, 8, 256)    0           batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     16448       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 8, 8, 64)     256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 64)     0           batch_normalization_47[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 128)    8320        add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 8, 8, 128)    512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_26 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_27 (DepthwiseC (None, 8, 8, 128)    1280        batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 8, 8, 128)    512         depthwise_conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 8, 8, 256)    0           batch_normalization_49[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 64)     16448       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 8, 8, 64)     256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 64)     0           batch_normalization_51[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 64)           0           add_9[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           4160        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            130         dense[0][0]
# ==================================================================================================
# Total params: 246,946
# Trainable params: 238,338
# Non-trainable params: 8,608
# __________________________________________________________________________________________________

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5",
    monitor='val_auc',
    mode='max',
    verbose = 1,
    save_best_only=True)

# %%
sig32_hist = sig32_model.fit(x=train_generator,
                              validation_data=test_generator,
                              epochs = 50,
                              callbacks=[model_checkpoint_callback]
                              )
# Out:
# Epoch 1/50
# 52/52 [==============================] - 46s 175ms/step - loss: 0.6474 - auc: 0.7605 - accuracy: 0.7026 - val_loss: 0.7054 - val_auc: 0.4728 - val_accuracy: 0.4960
#
# Epoch 00001: val_auc improved from -inf to 0.47279, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5
# Epoch 2/50
# 52/52 [==============================] - 8s 146ms/step - loss: 0.3855 - auc: 0.9099 - accuracy: 0.8244 - val_loss: 0.7228 - val_auc: 0.4384 - val_accuracy: 0.5040
#
# Epoch 00002: val_auc did not improve from 0.47279
# Epoch 3/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.3141 - auc: 0.9401 - accuracy: 0.8724 - val_loss: 1.1432 - val_auc: 0.4741 - val_accuracy: 0.5040
#
# Epoch 00003: val_auc improved from 0.47279 to 0.47407, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5
# Epoch 4/50
# 52/52 [==============================] - 8s 144ms/step - loss: 0.2430 - auc: 0.9641 - accuracy: 0.9041 - val_loss: 2.6241 - val_auc: 0.4647 - val_accuracy: 0.5040
#
# Epoch 00004: val_auc did not improve from 0.47407
# Epoch 5/50
# 52/52 [==============================] - 7s 144ms/step - loss: 0.1977 - auc: 0.9767 - accuracy: 0.9221 - val_loss: 3.4462 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00005: val_auc improved from 0.47407 to 0.50400, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5
# Epoch 6/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.1784 - auc: 0.9814 - accuracy: 0.9321 - val_loss: 6.6619 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00006: val_auc did not improve from 0.50400
# Epoch 7/50
# 52/52 [==============================] - 8s 145ms/step - loss: 0.1688 - auc: 0.9827 - accuracy: 0.9373 - val_loss: 4.1094 - val_auc: 0.5332 - val_accuracy: 0.5040
#
# Epoch 00007: val_auc improved from 0.50400 to 0.53323, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5
# Epoch 8/50
# 52/52 [==============================] - 7s 144ms/step - loss: 0.1527 - auc: 0.9844 - accuracy: 0.9497 - val_loss: 0.3498 - val_auc: 0.9474 - val_accuracy: 0.8600
#
# Epoch 00008: val_auc improved from 0.53323 to 0.94744, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5
# Epoch 9/50
# 52/52 [==============================] - 7s 144ms/step - loss: 0.1240 - auc: 0.9905 - accuracy: 0.9510 - val_loss: 0.5231 - val_auc: 0.9331 - val_accuracy: 0.8600
#
# Epoch 00009: val_auc did not improve from 0.94744
# Epoch 10/50
# 52/52 [==============================] - 7s 144ms/step - loss: 0.1065 - auc: 0.9931 - accuracy: 0.9536 - val_loss: 0.1216 - val_auc: 0.9910 - val_accuracy: 0.9640
#
# Epoch 00010: val_auc improved from 0.94744 to 0.99103, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5
# Epoch 11/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0965 - auc: 0.9938 - accuracy: 0.9701 - val_loss: 0.3265 - val_auc: 0.9525 - val_accuracy: 0.8640
#
# Epoch 00011: val_auc did not improve from 0.99103
# Epoch 12/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.1103 - auc: 0.9921 - accuracy: 0.9591 - val_loss: 1.7049 - val_auc: 0.8110 - val_accuracy: 0.7600
#
# Epoch 00012: val_auc did not improve from 0.99103
# Epoch 13/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.1075 - auc: 0.9910 - accuracy: 0.9603 - val_loss: 0.5120 - val_auc: 0.9222 - val_accuracy: 0.8280
#
# Epoch 00013: val_auc did not improve from 0.99103
# Epoch 14/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0745 - auc: 0.9961 - accuracy: 0.9730 - val_loss: 0.2421 - val_auc: 0.9796 - val_accuracy: 0.9300
#
# Epoch 00014: val_auc did not improve from 0.99103
# Epoch 15/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0771 - auc: 0.9953 - accuracy: 0.9723 - val_loss: 2.7702 - val_auc: 0.6647 - val_accuracy: 0.6040
#
# Epoch 00015: val_auc did not improve from 0.99103
# Epoch 16/50
# 52/52 [==============================] - 7s 144ms/step - loss: 0.0574 - auc: 0.9978 - accuracy: 0.9805 - val_loss: 1.1569 - val_auc: 0.8278 - val_accuracy: 0.7340
#
# Epoch 00016: val_auc did not improve from 0.99103
# Epoch 17/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0332 - auc: 0.9993 - accuracy: 0.9868 - val_loss: 0.7111 - val_auc: 0.9163 - val_accuracy: 0.8460
#
# Epoch 00017: val_auc did not improve from 0.99103
# Epoch 18/50
# 52/52 [==============================] - 7s 141ms/step - loss: 0.0543 - auc: 0.9983 - accuracy: 0.9772 - val_loss: 0.9514 - val_auc: 0.8904 - val_accuracy: 0.8200
#
# Epoch 00018: val_auc did not improve from 0.99103
# Epoch 19/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0415 - auc: 0.9984 - accuracy: 0.9851 - val_loss: 0.5314 - val_auc: 0.9481 - val_accuracy: 0.8900
#
# Epoch 00019: val_auc did not improve from 0.99103
# Epoch 20/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0832 - auc: 0.9950 - accuracy: 0.9754 - val_loss: 2.0438 - val_auc: 0.6952 - val_accuracy: 0.5680
#
# Epoch 00020: val_auc did not improve from 0.99103
# Epoch 21/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0376 - auc: 0.9990 - accuracy: 0.9845 - val_loss: 0.4081 - val_auc: 0.9548 - val_accuracy: 0.8920
#
# Epoch 00021: val_auc did not improve from 0.99103
# Epoch 22/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0456 - auc: 0.9964 - accuracy: 0.9887 - val_loss: 1.1323 - val_auc: 0.8835 - val_accuracy: 0.8500
#
# Epoch 00022: val_auc did not improve from 0.99103
# Epoch 23/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0441 - auc: 0.9989 - accuracy: 0.9795 - val_loss: 0.2484 - val_auc: 0.9795 - val_accuracy: 0.9460
#
# Epoch 00023: val_auc did not improve from 0.99103
# Epoch 24/50
# 52/52 [==============================] - 7s 141ms/step - loss: 0.0373 - auc: 0.9991 - accuracy: 0.9856 - val_loss: 0.3199 - val_auc: 0.9658 - val_accuracy: 0.9100
#
# Epoch 00024: val_auc did not improve from 0.99103
# Epoch 25/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0680 - auc: 0.9963 - accuracy: 0.9737 - val_loss: 0.2580 - val_auc: 0.9795 - val_accuracy: 0.9300
#
# Epoch 00025: val_auc did not improve from 0.99103
# Epoch 26/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0593 - auc: 0.9967 - accuracy: 0.9750 - val_loss: 2.9368 - val_auc: 0.6172 - val_accuracy: 0.5260
#
# Epoch 00026: val_auc did not improve from 0.99103
# Epoch 27/50
# 52/52 [==============================] - 7s 140ms/step - loss: 0.0292 - auc: 0.9995 - accuracy: 0.9901 - val_loss: 0.4322 - val_auc: 0.9512 - val_accuracy: 0.8780
#
# Epoch 00027: val_auc did not improve from 0.99103
# Epoch 28/50
# 52/52 [==============================] - 7s 141ms/step - loss: 0.0172 - auc: 0.9998 - accuracy: 0.9950 - val_loss: 1.2039 - val_auc: 0.8593 - val_accuracy: 0.7880
#
# Epoch 00028: val_auc did not improve from 0.99103
# Epoch 29/50
# 52/52 [==============================] - 7s 141ms/step - loss: 0.0413 - auc: 0.9985 - accuracy: 0.9857 - val_loss: 9.9437 - val_auc: 0.5099 - val_accuracy: 0.4960
#
# Epoch 00029: val_auc did not improve from 0.99103
# Epoch 30/50
# 52/52 [==============================] - 7s 140ms/step - loss: 0.0423 - auc: 0.9988 - accuracy: 0.9858 - val_loss: 2.2376 - val_auc: 0.7860 - val_accuracy: 0.7420
#
# Epoch 00030: val_auc did not improve from 0.99103
# Epoch 31/50
# 52/52 [==============================] - 7s 141ms/step - loss: 0.0476 - auc: 0.9986 - accuracy: 0.9787 - val_loss: 0.1623 - val_auc: 0.9868 - val_accuracy: 0.9560
#
# Epoch 00031: val_auc did not improve from 0.99103
# Epoch 32/50
# 52/52 [==============================] - 8s 144ms/step - loss: 0.0760 - auc: 0.9961 - accuracy: 0.9761 - val_loss: 0.2593 - val_auc: 0.9675 - val_accuracy: 0.8880
#
# Epoch 00032: val_auc did not improve from 0.99103
# Epoch 33/50
# 52/52 [==============================] - 8s 145ms/step - loss: 0.0165 - auc: 0.9998 - accuracy: 0.9960 - val_loss: 0.0770 - val_auc: 0.9947 - val_accuracy: 0.9780
#
# Epoch 00033: val_auc improved from 0.99103 to 0.99469, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5
# Epoch 34/50
# 52/52 [==============================] - 8s 144ms/step - loss: 0.0240 - auc: 0.9994 - accuracy: 0.9905 - val_loss: 0.4193 - val_auc: 0.9671 - val_accuracy: 0.9220
#
# Epoch 00034: val_auc did not improve from 0.99469
# Epoch 35/50
# 52/52 [==============================] - 8s 144ms/step - loss: 0.0351 - auc: 0.9990 - accuracy: 0.9871 - val_loss: 1.5061 - val_auc: 0.7744 - val_accuracy: 0.6700
#
# Epoch 00035: val_auc did not improve from 0.99469
# Epoch 36/50
# 52/52 [==============================] - 7s 145ms/step - loss: 0.0488 - auc: 0.9983 - accuracy: 0.9829 - val_loss: 0.6390 - val_auc: 0.9188 - val_accuracy: 0.8820
#
# Epoch 00036: val_auc did not improve from 0.99469
# Epoch 37/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0147 - auc: 0.9995 - accuracy: 0.9949 - val_loss: 0.0978 - val_auc: 0.9917 - val_accuracy: 0.9700
#
# Epoch 00037: val_auc did not improve from 0.99469
# Epoch 38/50
# 52/52 [==============================] - 7s 141ms/step - loss: 0.0419 - auc: 0.9990 - accuracy: 0.9853 - val_loss: 1.0724 - val_auc: 0.8869 - val_accuracy: 0.8500
#
# Epoch 00038: val_auc did not improve from 0.99469
# Epoch 39/50
# 52/52 [==============================] - 7s 140ms/step - loss: 0.0202 - auc: 0.9997 - accuracy: 0.9920 - val_loss: 0.5799 - val_auc: 0.9319 - val_accuracy: 0.8800
#
# Epoch 00039: val_auc did not improve from 0.99469
# Epoch 40/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0319 - auc: 0.9993 - accuracy: 0.9873 - val_loss: 0.3211 - val_auc: 0.9743 - val_accuracy: 0.9360
#
# Epoch 00040: val_auc did not improve from 0.99469
# Epoch 41/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0302 - auc: 0.9994 - accuracy: 0.9896 - val_loss: 0.0070 - val_auc: 1.0000 - val_accuracy: 0.9980
#
# Epoch 00041: val_auc improved from 0.99469 to 0.99998, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5
# Epoch 42/50
# 52/52 [==============================] - 7s 144ms/step - loss: 0.0227 - auc: 0.9995 - accuracy: 0.9888 - val_loss: 0.7687 - val_auc: 0.9344 - val_accuracy: 0.8920
#
# Epoch 00042: val_auc did not improve from 0.99998
# Epoch 43/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0537 - auc: 0.9958 - accuracy: 0.9839 - val_loss: 0.1102 - val_auc: 0.9940 - val_accuracy: 0.9460
#
# Epoch 00043: val_auc did not improve from 0.99998
# Epoch 44/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0136 - auc: 0.9999 - accuracy: 0.9944 - val_loss: 1.7670 - val_auc: 0.8561 - val_accuracy: 0.8260
#
# Epoch 00044: val_auc did not improve from 0.99998
# Epoch 45/50
# 52/52 [==============================] - 8s 145ms/step - loss: 0.0341 - auc: 0.9988 - accuracy: 0.9892 - val_loss: 0.2321 - val_auc: 0.9749 - val_accuracy: 0.9040
#
# Epoch 00045: val_auc did not improve from 0.99998
# Epoch 46/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0133 - auc: 0.9999 - accuracy: 0.9947 - val_loss: 0.6619 - val_auc: 0.9486 - val_accuracy: 0.9140
#
# Epoch 00046: val_auc did not improve from 0.99998
# Epoch 47/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0304 - auc: 0.9992 - accuracy: 0.9899 - val_loss: 0.3780 - val_auc: 0.9642 - val_accuracy: 0.9420
#
# Epoch 00047: val_auc did not improve from 0.99998
# Epoch 48/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0249 - auc: 0.9996 - accuracy: 0.9899 - val_loss: 0.4057 - val_auc: 0.9566 - val_accuracy: 0.8840
#
# Epoch 00048: val_auc did not improve from 0.99998
# Epoch 49/50
# 52/52 [==============================] - 7s 142ms/step - loss: 0.0148 - auc: 0.9999 - accuracy: 0.9978 - val_loss: 0.0251 - val_auc: 0.9979 - val_accuracy: 0.9980
#
# Epoch 00049: val_auc did not improve from 0.99998
# Epoch 50/50
# 52/52 [==============================] - 7s 143ms/step - loss: 0.0090 - auc: 0.9999 - accuracy: 0.9936 - val_loss: 7.2530 - val_auc: 0.6455 - val_accuracy: 0.6120
#
# Epoch 00050: val_auc did not improve from 0.99998

# %%
sig32_model = load_model("/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_32.hdf5")

# %%
y_actual2 , y_test2 = [],[]

# %%
for i in os.listdir("/content/sign_data_mod_mod/test/GENUINE/"):
    img=image.load_img("/content/sign_data_mod_mod/test/GENUINE/"+i,target_size=(32,32),color_mode='grayscale')
    img2=image.img_to_array(img)
    img3=img2/255.0
    img4=np.expand_dims(img3,axis=0)
    pred=sig32_model.predict(img4)
    pred1 = np.argmax(pred,axis=-1)
    y_test2.append(pred1[0])
    y_actual2.append(1)

# %%
for i in os.listdir("/content/sign_data_mod_mod/test/FORGED/"):
    img=image.load_img("/content/sign_data_mod_mod/test/FORGED/"+i,target_size=(32,32),color_mode='grayscale')
    img2=image.img_to_array(img)
    img3=img2/255.0
    img4=np.expand_dims(img3,axis=0)
    pred=sig32_model.predict(img4)
    pred1 = np.argmax(pred,axis=-1)
    y_test2.append(pred1[0])
    y_actual2.append(0)

# %%
y_actual2=np.array(y_actual2)
y_test2=np.array(y_test2)

# %%
cn2=confusion_matrix(y_actual2,y_test2)
print(metrics.classification_report(y_actual2,y_test2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       248
#            1       1.00      1.00      1.00       252
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500

# %%
sns.heatmap(cn2,cmap="icefire",annot=True)

# %%
acc = sig32_hist.history['accuracy']
val_acc = sig32_hist.history['val_accuracy']

auc = sig32_hist.history['auc']
val_auc = sig32_hist.history['val_auc']
epochs_range = range(50)

plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, auc, label='Training auc')
plt.plot(epochs_range, val_auc, label='Validation auc')
plt.legend(loc='upper right')
plt.title('Training and Validation auc')
plt.show()

# %%
train_datagen = image.ImageDataGenerator(rescale = 1./255)
test_datagen = image.ImageDataGenerator(rescale= 1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (64,64),
    color_mode='grayscale',
    batch_size = 32,
    class_mode = "categorical"
    )
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (64,64),
    color_mode='grayscale',
    batch_size = 32,
    class_mode = "categorical"
    )
# Out:
# Found 1649 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'FORGED': 0, 'GENUINE': 1}

# %%
def Network64(input_shape, nb_class, depth):
  xin = Input(shape= input_shape)

  x = Conv2D(16, kernel_size = (5,5), strides= (1,1), padding = 'same', activation='relu')(xin)
  x = BatchNormalization()(x)

  x = Conv2D(32, kernel_size = (3,3), strides= (2,2), padding = 'same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=4, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=4)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=64, max_dilation=3, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=64, max_dilation=3)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=128, max_dilation=2, number_of_units=depth)

  x = GlobalAveragePooling2D()(x)

  x = Dense(64, activation='relu')(x)
  x = Dense(nb_class, activation= 'softmax')(x)

  model = Model(xin, x)

  model.compile(loss='categorical_crossentropy', optimizer = keras.optimizers.Adam(learning_rate=0.01), metrics = [tf.keras.metrics.AUC(),"accuracy"])

  return model

# %%
sig64_model = Network64(input_shape = (64, 64, 1), nb_class = 2 , depth = 5)
sig64_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 16)   416         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   4640        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   2112        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 32, 32, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 32, 32, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 32, 32, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 32, 32, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 256)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   8224        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           batch_normalization_7[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   2112        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 32, 32, 64)   640         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 32, 32, 64)   640         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 32, 32, 64)   640         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 32, 32, 64)   640         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 64)   256         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           batch_normalization_9[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           batch_normalization_13[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   2112        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 32, 32, 64)   640         batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 32, 32, 64)   640         batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 256)  0           batch_normalization_15[0][0]
#                                                                  batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 32)   8224        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           batch_normalization_19[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   2112        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 256)  0           batch_normalization_21[0][0]
#                                                                  batch_normalization_22[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 32)   8224        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 32)   0           batch_normalization_25[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 64)   2112        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_18 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_19 (DepthwiseC (None, 32, 32, 64)   640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 64)   256         depthwise_conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 256)  0           batch_normalization_27[0][0]
#                                                                  batch_normalization_28[0][0]
#                                                                  batch_normalization_29[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 32)   8224        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 32)   0           batch_normalization_31[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  4224        add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_21 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_22 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 128)  0           depthwise_conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 128)  0           depthwise_conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           depthwise_conv2d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 128)  512         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 128)  512         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 128)  512         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 128)  512         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 512)  0           batch_normalization_33[0][0]
#                                                                  batch_normalization_34[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   32832       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 16, 16, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  8320        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_25 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_26 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 384)  0           batch_normalization_39[0][0]
#                                                                  batch_normalization_40[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   24640       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 64)   0           batch_normalization_42[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 128)  8320        add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 16, 16, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_27 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_28 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_29 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 384)  0           batch_normalization_44[0][0]
#                                                                  batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   24640       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 64)   0           batch_normalization_47[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 128)  8320        add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_30 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_31 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_32 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 384)  0           batch_normalization_49[0][0]
#                                                                  batch_normalization_50[0][0]
#                                                                  batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 64)   24640       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 16, 16, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 64)   0           batch_normalization_52[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 128)  8320        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 16, 16, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_33 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_34 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_35 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 384)  0           batch_normalization_54[0][0]
#                                                                  batch_normalization_55[0][0]
#                                                                  batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 64)   24640       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 16, 16, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 64)   0           batch_normalization_57[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 128)  8320        add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 16, 16, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_36 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_37 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_38 (DepthwiseC (None, 16, 16, 128)  1280        batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 16, 16, 128)  512         depthwise_conv2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 16, 16, 384)  0           batch_normalization_59[0][0]
#                                                                  batch_normalization_60[0][0]
#                                                                  batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 64)   24640       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 16, 16, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 64)   0           batch_normalization_62[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 256)  16640       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 16, 16, 256)  1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_39 (DepthwiseC (None, 16, 16, 256)  2560        batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_40 (DepthwiseC (None, 16, 16, 256)  2560        batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_41 (DepthwiseC (None, 16, 16, 256)  2560        batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 256)    0           depthwise_conv2d_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 256)    0           depthwise_conv2d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 256)    0           depthwise_conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 8, 8, 256)    1024        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 8, 8, 256)    1024        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 8, 8, 256)    1024        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 768)    0           batch_normalization_64[0][0]
#                                                                  batch_normalization_65[0][0]
#                                                                  batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 128)    98432       concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 8, 8, 128)    512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 256)    33024       batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 8, 8, 256)    1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_42 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_43 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 8, 8, 512)    0           batch_normalization_69[0][0]
#                                                                  batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    65664       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 128)    512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 128)    0           batch_normalization_71[0][0]
#                                                                  batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 256)    33024       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 8, 8, 256)    1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_44 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_45 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 8, 8, 512)    0           batch_normalization_73[0][0]
#                                                                  batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 128)    65664       concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 128)    512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 128)    0           batch_normalization_75[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 256)    33024       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 256)    1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_46 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_47 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 8, 8, 512)    0           batch_normalization_77[0][0]
#                                                                  batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 128)    65664       concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 128)    512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 128)    0           batch_normalization_79[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 256)    33024       add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 256)    1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_48 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_49 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 8, 8, 512)    0           batch_normalization_81[0][0]
#                                                                  batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 128)    65664       concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 128)    512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 128)    0           batch_normalization_83[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 256)    33024       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 256)    1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_50 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_51 (DepthwiseC (None, 8, 8, 256)    2560        batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 256)    1024        depthwise_conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 8, 8, 512)    0           batch_normalization_85[0][0]
#                                                                  batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 128)    65664       concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 128)    512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 128)    0           batch_normalization_87[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           add_14[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            130         dense[0][0]
# ==================================================================================================
# Total params: 989,986
# Trainable params: 967,938
# Non-trainable params: 22,048
# __________________________________________________________________________________________________

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5",
    monitor='val_auc',
    verbose = 1,
    mode='max',
    save_best_only=True)

# %%
sig64_hist = sig64_model.fit(x=train_generator,
                              validation_data=test_generator,
                              epochs = 50,
                              callbacks=[model_checkpoint_callback]
                              )
# Out:
# Epoch 1/50
# 52/52 [==============================] - 57s 303ms/step - loss: 0.9122 - auc: 0.7069 - accuracy: 0.6398 - val_loss: 0.6980 - val_auc: 0.4927 - val_accuracy: 0.5040
#
# Epoch 00001: val_auc improved from -inf to 0.49269, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5
# Epoch 2/50
# 52/52 [==============================] - 13s 254ms/step - loss: 0.2786 - auc: 0.9536 - accuracy: 0.9000 - val_loss: 1.3573 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00002: val_auc improved from 0.49269 to 0.50400, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5
# Epoch 3/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.1690 - auc: 0.9820 - accuracy: 0.9345 - val_loss: 1.9183 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00003: val_auc did not improve from 0.50400
# Epoch 4/50
# 52/52 [==============================] - 14s 260ms/step - loss: 0.1591 - auc: 0.9847 - accuracy: 0.9368 - val_loss: 3.7594 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00004: val_auc did not improve from 0.50400
# Epoch 5/50
# 52/52 [==============================] - 14s 259ms/step - loss: 0.0822 - auc: 0.9949 - accuracy: 0.9576 - val_loss: 3.2226 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00005: val_auc did not improve from 0.50400
# Epoch 6/50
# 52/52 [==============================] - 13s 258ms/step - loss: 0.1364 - auc: 0.9876 - accuracy: 0.9541 - val_loss: 5.8711 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00006: val_auc did not improve from 0.50400
# Epoch 7/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.0666 - auc: 0.9963 - accuracy: 0.9812 - val_loss: 4.6239 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00007: val_auc did not improve from 0.50400
# Epoch 8/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0741 - auc: 0.9967 - accuracy: 0.9706 - val_loss: 12.3807 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00008: val_auc did not improve from 0.50400
# Epoch 9/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.0681 - auc: 0.9967 - accuracy: 0.9725 - val_loss: 8.7423 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00009: val_auc did not improve from 0.50400
# Epoch 10/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0782 - auc: 0.9953 - accuracy: 0.9696 - val_loss: 1.7696 - val_auc: 0.7414 - val_accuracy: 0.6700
#
# Epoch 00010: val_auc improved from 0.50400 to 0.74142, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5
# Epoch 11/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0341 - auc: 0.9989 - accuracy: 0.9902 - val_loss: 0.4333 - val_auc: 0.9235 - val_accuracy: 0.8400
#
# Epoch 00011: val_auc improved from 0.74142 to 0.92346, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5
# Epoch 12/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0889 - auc: 0.9947 - accuracy: 0.9701 - val_loss: 2.8727 - val_auc: 0.7681 - val_accuracy: 0.7300
#
# Epoch 00012: val_auc did not improve from 0.92346
# Epoch 13/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0492 - auc: 0.9984 - accuracy: 0.9825 - val_loss: 0.6362 - val_auc: 0.9139 - val_accuracy: 0.8240
#
# Epoch 00013: val_auc did not improve from 0.92346
# Epoch 14/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0618 - auc: 0.9973 - accuracy: 0.9796 - val_loss: 0.1887 - val_auc: 0.9852 - val_accuracy: 0.9580
#
# Epoch 00014: val_auc improved from 0.92346 to 0.98524, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5
# Epoch 15/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0485 - auc: 0.9969 - accuracy: 0.9836 - val_loss: 3.8269 - val_auc: 0.7635 - val_accuracy: 0.7440
#
# Epoch 00015: val_auc did not improve from 0.98524
# Epoch 16/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.0410 - auc: 0.9978 - accuracy: 0.9875 - val_loss: 0.3306 - val_auc: 0.9735 - val_accuracy: 0.9420
#
# Epoch 00016: val_auc did not improve from 0.98524
# Epoch 17/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.0272 - auc: 0.9986 - accuracy: 0.9927 - val_loss: 1.1286 - val_auc: 0.8743 - val_accuracy: 0.8260
#
# Epoch 00017: val_auc did not improve from 0.98524
# Epoch 18/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0327 - auc: 0.9984 - accuracy: 0.9886 - val_loss: 0.9271 - val_auc: 0.8788 - val_accuracy: 0.7920
#
# Epoch 00018: val_auc did not improve from 0.98524
# Epoch 19/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0332 - auc: 0.9986 - accuracy: 0.9871 - val_loss: 0.1781 - val_auc: 0.9847 - val_accuracy: 0.9700
#
# Epoch 00019: val_auc did not improve from 0.98524
# Epoch 20/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.0638 - auc: 0.9960 - accuracy: 0.9820 - val_loss: 0.7904 - val_auc: 0.9374 - val_accuracy: 0.9160
#
# Epoch 00020: val_auc did not improve from 0.98524
# Epoch 21/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0365 - auc: 0.9976 - accuracy: 0.9882 - val_loss: 1.4865 - val_auc: 0.7773 - val_accuracy: 0.6780
#
# Epoch 00021: val_auc did not improve from 0.98524
# Epoch 22/50
# 52/52 [==============================] - 13s 258ms/step - loss: 0.0070 - auc: 0.9999 - accuracy: 0.9990 - val_loss: 0.1688 - val_auc: 0.9863 - val_accuracy: 0.9540
#
# Epoch 00022: val_auc improved from 0.98524 to 0.98634, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5
# Epoch 23/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0190 - auc: 0.9995 - accuracy: 0.9959 - val_loss: 0.3620 - val_auc: 0.9618 - val_accuracy: 0.8980
#
# Epoch 00023: val_auc did not improve from 0.98634
# Epoch 24/50
# 52/52 [==============================] - 13s 258ms/step - loss: 0.0269 - auc: 0.9993 - accuracy: 0.9928 - val_loss: 0.3067 - val_auc: 0.9720 - val_accuracy: 0.9560
#
# Epoch 00024: val_auc did not improve from 0.98634
# Epoch 25/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0269 - auc: 0.9995 - accuracy: 0.9908 - val_loss: 0.0263 - val_auc: 0.9998 - val_accuracy: 0.9900
#
# Epoch 00025: val_auc improved from 0.98634 to 0.99980, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5
# Epoch 26/50
# 52/52 [==============================] - 14s 257ms/step - loss: 0.0396 - auc: 0.9982 - accuracy: 0.9865 - val_loss: 0.0241 - val_auc: 0.9997 - val_accuracy: 0.9900
#
# Epoch 00026: val_auc did not improve from 0.99980
# Epoch 27/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0183 - auc: 0.9998 - accuracy: 0.9931 - val_loss: 7.7343 - val_auc: 0.6472 - val_accuracy: 0.6360
#
# Epoch 00027: val_auc did not improve from 0.99980
# Epoch 28/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0241 - auc: 0.9989 - accuracy: 0.9912 - val_loss: 0.2323 - val_auc: 0.9790 - val_accuracy: 0.9480
#
# Epoch 00028: val_auc did not improve from 0.99980
# Epoch 29/50
# 52/52 [==============================] - 13s 258ms/step - loss: 0.0179 - auc: 0.9998 - accuracy: 0.9947 - val_loss: 0.0029 - val_auc: 1.0000 - val_accuracy: 1.0000
#
# Epoch 00029: val_auc improved from 0.99980 to 1.00000, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5
# Epoch 30/50
# 52/52 [==============================] - 13s 259ms/step - loss: 0.0336 - auc: 0.9993 - accuracy: 0.9895 - val_loss: 5.3419 - val_auc: 0.5940 - val_accuracy: 0.5680
#
# Epoch 00030: val_auc did not improve from 1.00000
# Epoch 31/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0310 - auc: 0.9994 - accuracy: 0.9899 - val_loss: 2.1767 - val_auc: 0.7605 - val_accuracy: 0.7340
#
# Epoch 00031: val_auc did not improve from 1.00000
# Epoch 32/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0370 - auc: 0.9992 - accuracy: 0.9854 - val_loss: 0.3788 - val_auc: 0.9671 - val_accuracy: 0.9440
#
# Epoch 00032: val_auc did not improve from 1.00000
# Epoch 33/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0083 - auc: 0.9999 - accuracy: 0.9981 - val_loss: 3.6626 - val_auc: 0.5929 - val_accuracy: 0.5460
#
# Epoch 00033: val_auc did not improve from 1.00000
# Epoch 34/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0729 - auc: 0.9956 - accuracy: 0.9735 - val_loss: 11.4274 - val_auc: 0.4980 - val_accuracy: 0.4960
#
# Epoch 00034: val_auc did not improve from 1.00000
# Epoch 35/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0393 - auc: 0.9981 - accuracy: 0.9868 - val_loss: 0.0851 - val_auc: 0.9967 - val_accuracy: 0.9660
#
# Epoch 00035: val_auc did not improve from 1.00000
# Epoch 36/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.0474 - auc: 0.9982 - accuracy: 0.9825 - val_loss: 0.5474 - val_auc: 0.9144 - val_accuracy: 0.8620
#
# Epoch 00036: val_auc did not improve from 1.00000
# Epoch 37/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.0168 - auc: 0.9999 - accuracy: 0.9931 - val_loss: 0.0557 - val_auc: 0.9973 - val_accuracy: 0.9800
#
# Epoch 00037: val_auc did not improve from 1.00000
# Epoch 38/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0482 - auc: 0.9975 - accuracy: 0.9837 - val_loss: 0.6500 - val_auc: 0.9522 - val_accuracy: 0.9520
#
# Epoch 00038: val_auc did not improve from 1.00000
# Epoch 39/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.1732 - auc: 0.9805 - accuracy: 0.9397 - val_loss: 0.9400 - val_auc: 0.9442 - val_accuracy: 0.9100
#
# Epoch 00039: val_auc did not improve from 1.00000
# Epoch 40/50
# 52/52 [==============================] - 13s 258ms/step - loss: 0.1058 - auc: 0.9914 - accuracy: 0.9719 - val_loss: 2.7112 - val_auc: 0.6770 - val_accuracy: 0.5400
#
# Epoch 00040: val_auc did not improve from 1.00000
# Epoch 41/50
# 52/52 [==============================] - 14s 259ms/step - loss: 0.1330 - auc: 0.9897 - accuracy: 0.9434 - val_loss: 1.7379 - val_auc: 0.7425 - val_accuracy: 0.6380
#
# Epoch 00041: val_auc did not improve from 1.00000
# Epoch 42/50
# 52/52 [==============================] - 13s 258ms/step - loss: 0.0304 - auc: 0.9994 - accuracy: 0.9895 - val_loss: 0.0316 - val_auc: 0.9995 - val_accuracy: 0.9900
#
# Epoch 00042: val_auc did not improve from 1.00000
# Epoch 43/50
# 52/52 [==============================] - 13s 258ms/step - loss: 0.0542 - auc: 0.9981 - accuracy: 0.9827 - val_loss: 2.1770 - val_auc: 0.6946 - val_accuracy: 0.5840
#
# Epoch 00043: val_auc did not improve from 1.00000
# Epoch 44/50
# 52/52 [==============================] - 14s 259ms/step - loss: 0.0368 - auc: 0.9987 - accuracy: 0.9851 - val_loss: 2.9779 - val_auc: 0.6704 - val_accuracy: 0.6020
#
# Epoch 00044: val_auc did not improve from 1.00000
# Epoch 45/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0130 - auc: 0.9999 - accuracy: 0.9964 - val_loss: 38.9720 - val_auc: 0.4960 - val_accuracy: 0.4960
#
# Epoch 00045: val_auc did not improve from 1.00000
# Epoch 46/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0056 - auc: 1.0000 - accuracy: 0.9971 - val_loss: 0.7666 - val_auc: 0.8954 - val_accuracy: 0.8140
#
# Epoch 00046: val_auc did not improve from 1.00000
# Epoch 47/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0164 - auc: 0.9998 - accuracy: 0.9947 - val_loss: 4.5123 - val_auc: 0.6756 - val_accuracy: 0.6460
#
# Epoch 00047: val_auc did not improve from 1.00000
# Epoch 48/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.0391 - auc: 0.9977 - accuracy: 0.9897 - val_loss: 0.0126 - val_auc: 0.9999 - val_accuracy: 0.9940
#
# Epoch 00048: val_auc did not improve from 1.00000
# Epoch 49/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0164 - auc: 0.9998 - accuracy: 0.9953 - val_loss: 0.0071 - val_auc: 1.0000 - val_accuracy: 0.9940
#
# Epoch 00049: val_auc did not improve from 1.00000
# Epoch 50/50
# 52/52 [==============================] - 13s 256ms/step - loss: 0.0302 - auc: 0.9995 - accuracy: 0.9903 - val_loss: 1.6148 - val_auc: 0.8882 - val_accuracy: 0.8520
#
# Epoch 00050: val_auc did not improve from 1.00000

# %%
sig64_model = load_model('/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_64.hdf5')

# %%
y_actual2 , y_test2 = [],[]

# %%
for i in os.listdir("/content/sign_data_mod_mod/test/GENUINE/"):
    img=image.load_img("/content/sign_data_mod_mod/test/GENUINE/"+i,target_size=(64,64),color_mode='grayscale')
    img2=image.img_to_array(img)
    img3=img2/255.0
    img4=np.expand_dims(img3,axis=0)
    pred=sig64_model.predict(img4)
    pred1 = np.argmax(pred,axis=-1)
    y_test2.append(pred1[0])
    y_actual2.append(1)

# %%
for i in os.listdir("/content/sign_data_mod_mod/test/FORGED/"):
    img=image.load_img("/content/sign_data_mod_mod/test/FORGED/"+i,target_size=(64,64),color_mode='grayscale')
    img2=image.img_to_array(img)
    img3=img2/255.0
    img4=np.expand_dims(img3,axis=0)
    pred=sig64_model.predict(img4)
    pred1 = np.argmax(pred,axis=-1)
    y_test2.append(pred1[0])
    y_actual2.append(0)

# %%
y_actual2=np.array(y_actual2)
y_test2=np.array(y_test2)

# %%
cn2=confusion_matrix(y_actual2,y_test2)
print(metrics.classification_report(y_actual2,y_test2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       248
#            1       1.00      1.00      1.00       252
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500

# %%
sns.heatmap(cn2,cmap="icefire",annot=True)

# %%
acc = sig64_hist.history['accuracy']
val_acc = sig64_hist.history['val_accuracy']

auc = sig64_hist.history['auc']
val_auc = sig64_hist.history['val_auc']
epochs_range = range(50)

plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, auc, label='Training auc')
plt.plot(epochs_range, val_auc, label='Validation auc')
plt.legend(loc='upper right')
plt.title('Training and Validation auc')
plt.show()

# %%
train_datagen = image.ImageDataGenerator(rescale = 1./255)
test_datagen = image.ImageDataGenerator(rescale= 1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (128,128),
    color_mode='grayscale',
    batch_size = 32,
    class_mode = "categorical"
    )
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (128,128),
    color_mode='grayscale',
    batch_size = 32,
    class_mode = "categorical"
    )
# Out:
# Found 1649 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'FORGED': 0, 'GENUINE': 1}

# %%
def Network128(input_shape, nb_class, depth):
  xin = Input(shape= input_shape)

  x = Conv2D(16, kernel_size = (5,5), strides= (1,1), padding = 'same', activation='relu')(xin)
  x = BatchNormalization()(x)

  x = Conv2D(32, kernel_size = (3,3), strides= (2,2), padding = 'same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=5, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=5)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=64, max_dilation=4, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=64, max_dilation=4)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=128, max_dilation=3, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=128, max_dilation=3)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=256, max_dilation=2, number_of_units=depth)

  x = GlobalAveragePooling2D()(x)

  x = Dense(128, activation='relu')(x)
  x = Dense(64, activation='relu')(x)

  x = Dense(nb_class, activation= 'softmax')(x)

  model = Model(xin, x)

  model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.01) , metrics = [tf.keras.metrics.AUC(),"accuracy"])

  return model

# %%
sig128_model = Network128(input_shape = (128, 128, 1), nb_class = 2 , depth = 5)
sig128_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 16) 416         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   4640        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   2112        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 64, 64, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 64, 64, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 64, 64, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 64, 64, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 64, 64, 64)   640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64)   256         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 320)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   10272       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 32)   0           batch_normalization_8[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   2112        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 64, 64, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 64, 64, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 64, 64, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 64, 64, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 64, 64, 64)   640         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
#                                                                  batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 32)   10272       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 32)   0           batch_normalization_15[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   2112        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 320)  0           batch_normalization_17[0][0]
#                                                                  batch_normalization_18[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_20[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 32)   10272       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 32)   0           batch_normalization_22[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 64)   2112        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_18 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_19 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 320)  0           batch_normalization_24[0][0]
#                                                                  batch_normalization_25[0][0]
#                                                                  batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 32)   10272       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 64, 64, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 32)   0           batch_normalization_29[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 64)   2112        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 64, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_21 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_22 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 64, 64, 64)   640         batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 64, 64, 64)   256         depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 320)  0           batch_normalization_31[0][0]
#                                                                  batch_normalization_32[0][0]
#                                                                  batch_normalization_33[0][0]
#                                                                  batch_normalization_34[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 32)   10272       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 64, 64, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 32)   0           batch_normalization_36[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  4224        add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 64, 64, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_25 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_26 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_27 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_28 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_29 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 128)  0           depthwise_conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           depthwise_conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0           depthwise_conv2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 128)  0           depthwise_conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 128)  0           depthwise_conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 32, 32, 128)  512         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 128)  512         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 128)  512         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 128)  512         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 32, 128)  512         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 640)  0           batch_normalization_38[0][0]
#                                                                  batch_normalization_39[0][0]
#                                                                  batch_normalization_40[0][0]
#                                                                  batch_normalization_41[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   41024       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 32, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 128)  8320        batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 32, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_30 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_31 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_32 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_33 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 512)  0           batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
#                                                                  batch_normalization_47[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 64)   32832       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 32, 32, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 64)   0           batch_normalization_49[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 128)  8320        add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 32, 32, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_34 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_35 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_36 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_37 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 512)  0           batch_normalization_51[0][0]
#                                                                  batch_normalization_52[0][0]
#                                                                  batch_normalization_53[0][0]
#                                                                  batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 64)   32832       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 32, 32, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 64)   0           batch_normalization_55[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 128)  8320        add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 32, 32, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_38 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_39 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_40 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_41 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_41[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 512)  0           batch_normalization_57[0][0]
#                                                                  batch_normalization_58[0][0]
#                                                                  batch_normalization_59[0][0]
#                                                                  batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 64)   32832       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 64)   0           batch_normalization_61[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 128)  8320        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_42 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_43 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_44 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_45 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 512)  0           batch_normalization_63[0][0]
#                                                                  batch_normalization_64[0][0]
#                                                                  batch_normalization_65[0][0]
#                                                                  batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 64)   32832       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 64)   0           batch_normalization_67[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 128)  8320        add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_46 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_47 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_48 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_49 (DepthwiseC (None, 32, 32, 128)  1280        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 32, 32, 128)  512         depthwise_conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 512)  0           batch_normalization_69[0][0]
#                                                                  batch_normalization_70[0][0]
#                                                                  batch_normalization_71[0][0]
#                                                                  batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 64)   32832       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 32, 32, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 64)   0           batch_normalization_73[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 256)  16640       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 32, 32, 256)  1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_50 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_51 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_52 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_53 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 256)  0           depthwise_conv2d_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 256)  0           depthwise_conv2d_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 256)  0           depthwise_conv2d_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 256)  0           depthwise_conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 16, 16, 256)  1024        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 16, 16, 256)  1024        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 16, 16, 256)  1024        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 16, 16, 256)  1024        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 16, 16, 1024) 0           batch_normalization_75[0][0]
#                                                                  batch_normalization_76[0][0]
#                                                                  batch_normalization_77[0][0]
#                                                                  batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 128)  131200      concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 16, 16, 128)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 256)  33024       batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 16, 16, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_54 (DepthwiseC (None, 16, 16, 256)  2560        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_55 (DepthwiseC (None, 16, 16, 256)  2560        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_56 (DepthwiseC (None, 16, 16, 256)  2560        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 16, 16, 256)  1024        depthwise_conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 16, 16, 256)  1024        depthwise_conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 16, 16, 256)  1024        depthwise_conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 16, 16, 768)  0           batch_normalization_81[0][0]
#                                                                  batch_normalization_82[0][0]
#                                                                  batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  98432       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 16, 16, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 128)  0           batch_normalization_84[0][0]
#                                                                  batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 256)  33024       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 16, 16, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_57 (DepthwiseC (None, 16, 16, 256)  2560        batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_58 (DepthwiseC (None, 16, 16, 256)  2560        batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_59 (DepthwiseC (None, 16, 16, 256)  2560        batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 16, 16, 256)  1024        depthwise_conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 16, 16, 256)  1024        depthwise_conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 16, 16, 256)  1024        depthwise_conv2d_59[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 16, 16, 768)  0           batch_normalization_86[0][0]
#                                                                  batch_normalization_87[0][0]
# ...
# concatenate_16 (Concatenate)    (None, 16, 16, 768)  0           batch_normalization_101[0][0]
#                                                                  batch_normalization_102[0][0]
#                                                                  batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 128)  98432       concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 16, 16, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 128)  0           batch_normalization_104[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 512)  66048       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 16, 16, 512)  2048        conv2d_36[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_69 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_70 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_71 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 8, 8, 512)    0           depthwise_conv2d_69[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 8, 8, 512)    0           depthwise_conv2d_70[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 8, 8, 512)    0           depthwise_conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 8, 8, 512)    2048        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 8, 8, 512)    2048        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 8, 8, 512)    2048        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 1536)   0           batch_normalization_106[0][0]
#                                                                  batch_normalization_107[0][0]
#                                                                  batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 256)    393472      concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 8, 8, 256)    1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 512)    131584      batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 8, 8, 512)    2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_72 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_73 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 8, 8, 1024)   0           batch_normalization_111[0][0]
#                                                                  batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 256)    262400      concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 8, 8, 256)    1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 256)    0           batch_normalization_113[0][0]
#                                                                  batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 512)    131584      add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 8, 8, 512)    2048        conv2d_40[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_74 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_75 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_75[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 8, 8, 1024)   0           batch_normalization_115[0][0]
#                                                                  batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 256)    262400      concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 8, 8, 256)    1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 256)    0           batch_normalization_117[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 512)    131584      add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 8, 8, 512)    2048        conv2d_42[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_76 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_77 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_77[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 1024)   0           batch_normalization_119[0][0]
#                                                                  batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 256)    262400      concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 8, 8, 256)    1024        conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           batch_normalization_121[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 512)    131584      add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 8, 8, 512)    2048        conv2d_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_78 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_79 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_79[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 8, 8, 1024)   0           batch_normalization_123[0][0]
#                                                                  batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 256)    262400      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 8, 8, 256)    1024        conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 256)    0           batch_normalization_125[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 512)    131584      add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 8, 8, 512)    2048        conv2d_46[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_80 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_81 (DepthwiseC (None, 8, 8, 512)    5120        batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 8, 8, 512)    2048        depthwise_conv2d_81[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 8, 8, 1024)   0           batch_normalization_127[0][0]
#                                                                  batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 256)    262400      concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 8, 8, 256)    1024        conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 8, 8, 256)    0           batch_normalization_129[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           add_19[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          32896       global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            130         dense_1[0][0]
# ==================================================================================================
# Total params: 3,856,674
# Trainable params: 3,806,850
# Non-trainable params: 49,824
# __________________________________________________________________________________________________

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5",
    monitor='val_auc',
    verbose = 1,
    mode='max',
    save_best_only=True)

# %%
sig128_hist = sig128_model.fit(x=train_generator,
                              validation_data=test_generator,
                              epochs = 50,
                              callbacks=[model_checkpoint_callback]
                              )
# Out:
# Epoch 1/50
# 52/52 [==============================] - 113s 1s/step - loss: 0.9689 - auc: 0.7631 - accuracy: 0.6943 - val_loss: 1.3143 - val_auc: 0.4960 - val_accuracy: 0.4960
#
# Epoch 00001: val_auc improved from -inf to 0.49600, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 2/50
# 52/52 [==============================] - 64s 1s/step - loss: 0.2806 - auc: 0.9528 - accuracy: 0.8893 - val_loss: 1.3584 - val_auc: 0.5050 - val_accuracy: 0.5040
#
# Epoch 00002: val_auc improved from 0.49600 to 0.50501, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 3/50
# 52/52 [==============================] - 64s 1s/step - loss: 0.2135 - auc: 0.9703 - accuracy: 0.9163 - val_loss: 1.5281 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00003: val_auc did not improve from 0.50501
# Epoch 4/50
# 52/52 [==============================] - 65s 1s/step - loss: 0.2641 - auc: 0.9704 - accuracy: 0.9145 - val_loss: 0.8714 - val_auc: 0.6090 - val_accuracy: 0.5040
#
# Epoch 00004: val_auc improved from 0.50501 to 0.60901, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 5/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.2477 - auc: 0.9627 - accuracy: 0.8995 - val_loss: 1.5302 - val_auc: 0.5906 - val_accuracy: 0.5040
#
# Epoch 00005: val_auc did not improve from 0.60901
# Epoch 6/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.1968 - auc: 0.9768 - accuracy: 0.9183 - val_loss: 2.6405 - val_auc: 0.5014 - val_accuracy: 0.5040
#
# Epoch 00006: val_auc did not improve from 0.60901
# Epoch 7/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.1141 - auc: 0.9913 - accuracy: 0.9537 - val_loss: 5.1294 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00007: val_auc did not improve from 0.60901
# Epoch 8/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.1081 - auc: 0.9916 - accuracy: 0.9612 - val_loss: 3.9934 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00008: val_auc did not improve from 0.60901
# Epoch 9/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.1238 - auc: 0.9902 - accuracy: 0.9533 - val_loss: 7.7023 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00009: val_auc did not improve from 0.60901
# Epoch 10/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0575 - auc: 0.9968 - accuracy: 0.9792 - val_loss: 8.5620 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00010: val_auc did not improve from 0.60901
# Epoch 11/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0416 - auc: 0.9986 - accuracy: 0.9899 - val_loss: 1.0652 - val_auc: 0.7502 - val_accuracy: 0.7120
#
# Epoch 00011: val_auc improved from 0.60901 to 0.75022, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 12/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0948 - auc: 0.9928 - accuracy: 0.9690 - val_loss: 0.8547 - val_auc: 0.8737 - val_accuracy: 0.8000
#
# Epoch 00012: val_auc improved from 0.75022 to 0.87366, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 13/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0977 - auc: 0.9938 - accuracy: 0.9608 - val_loss: 0.1115 - val_auc: 0.9914 - val_accuracy: 0.9720
#
# Epoch 00013: val_auc improved from 0.87366 to 0.99141, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 14/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0716 - auc: 0.9966 - accuracy: 0.9790 - val_loss: 0.1033 - val_auc: 0.9934 - val_accuracy: 0.9620
#
# Epoch 00014: val_auc improved from 0.99141 to 0.99341, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 15/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0584 - auc: 0.9975 - accuracy: 0.9769 - val_loss: 0.1886 - val_auc: 0.9848 - val_accuracy: 0.9380
#
# Epoch 00015: val_auc did not improve from 0.99341
# Epoch 16/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0331 - auc: 0.9994 - accuracy: 0.9841 - val_loss: 0.0268 - val_auc: 0.9978 - val_accuracy: 0.9920
#
# Epoch 00016: val_auc improved from 0.99341 to 0.99776, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 17/50
# 52/52 [==============================] - 67s 1s/step - loss: 0.0469 - auc: 0.9966 - accuracy: 0.9898 - val_loss: 0.9322 - val_auc: 0.8776 - val_accuracy: 0.8100
#
# Epoch 00017: val_auc did not improve from 0.99776
# Epoch 18/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0133 - auc: 0.9997 - accuracy: 0.9962 - val_loss: 0.0300 - val_auc: 0.9995 - val_accuracy: 0.9920
#
# Epoch 00018: val_auc improved from 0.99776 to 0.99951, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 19/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0228 - auc: 0.9992 - accuracy: 0.9922 - val_loss: 0.0774 - val_auc: 0.9973 - val_accuracy: 0.9660
#
# Epoch 00019: val_auc did not improve from 0.99951
# Epoch 20/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0313 - auc: 0.9994 - accuracy: 0.9853 - val_loss: 0.7604 - val_auc: 0.9176 - val_accuracy: 0.8740
#
# Epoch 00020: val_auc did not improve from 0.99951
# Epoch 21/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0269 - auc: 0.9995 - accuracy: 0.9921 - val_loss: 0.1394 - val_auc: 0.9910 - val_accuracy: 0.9780
#
# Epoch 00021: val_auc did not improve from 0.99951
# Epoch 22/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0309 - auc: 0.9993 - accuracy: 0.9890 - val_loss: 0.0113 - val_auc: 0.9999 - val_accuracy: 0.9940
#
# Epoch 00022: val_auc improved from 0.99951 to 0.99992, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 23/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0280 - auc: 0.9993 - accuracy: 0.9886 - val_loss: 4.8026 - val_auc: 0.7015 - val_accuracy: 0.6140
#
# Epoch 00023: val_auc did not improve from 0.99992
# Epoch 24/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0629 - auc: 0.9973 - accuracy: 0.9730 - val_loss: 2.0439 - val_auc: 0.8629 - val_accuracy: 0.8220
#
# Epoch 00024: val_auc did not improve from 0.99992
# Epoch 25/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0964 - auc: 0.9935 - accuracy: 0.9655 - val_loss: 1.9208 - val_auc: 0.7161 - val_accuracy: 0.6340
#
# Epoch 00025: val_auc did not improve from 0.99992
# Epoch 26/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0569 - auc: 0.9964 - accuracy: 0.9767 - val_loss: 0.0264 - val_auc: 0.9996 - val_accuracy: 0.9900
#
# Epoch 00026: val_auc did not improve from 0.99992
# Epoch 27/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0191 - auc: 0.9989 - accuracy: 0.9958 - val_loss: 0.1328 - val_auc: 0.9901 - val_accuracy: 0.9660
#
# Epoch 00027: val_auc did not improve from 0.99992
# Epoch 28/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0301 - auc: 0.9994 - accuracy: 0.9887 - val_loss: 0.1090 - val_auc: 0.9910 - val_accuracy: 0.9780
#
# Epoch 00028: val_auc did not improve from 0.99992
# Epoch 29/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0291 - auc: 0.9994 - accuracy: 0.9893 - val_loss: 0.1621 - val_auc: 0.9908 - val_accuracy: 0.9560
#
# Epoch 00029: val_auc did not improve from 0.99992
# Epoch 30/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0101 - auc: 0.9995 - accuracy: 0.9971 - val_loss: 0.9118 - val_auc: 0.7111 - val_accuracy: 0.5360
#
# Epoch 00030: val_auc did not improve from 0.99992
# Epoch 31/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0898 - auc: 0.9950 - accuracy: 0.9773 - val_loss: 1.1440 - val_auc: 0.8825 - val_accuracy: 0.8340
#
# Epoch 00031: val_auc did not improve from 0.99992
# Epoch 32/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0746 - auc: 0.9944 - accuracy: 0.9747 - val_loss: 1.3372 - val_auc: 0.8891 - val_accuracy: 0.8520
#
# Epoch 00032: val_auc did not improve from 0.99992
# Epoch 33/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0303 - auc: 0.9993 - accuracy: 0.9891 - val_loss: 1.8164 - val_auc: 0.7518 - val_accuracy: 0.6600
#
# Epoch 00033: val_auc did not improve from 0.99992
# Epoch 34/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0345 - auc: 0.9993 - accuracy: 0.9873 - val_loss: 0.0087 - val_auc: 1.0000 - val_accuracy: 0.9960
#
# Epoch 00034: val_auc improved from 0.99992 to 0.99998, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 35/50
# 52/52 [==============================] - 67s 1s/step - loss: 0.0062 - auc: 1.0000 - accuracy: 0.9977 - val_loss: 2.2180 - val_auc: 0.8117 - val_accuracy: 0.7720
#
# Epoch 00035: val_auc did not improve from 0.99998
# Epoch 36/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0017 - auc: 1.0000 - accuracy: 0.9997 - val_loss: 13.3927 - val_auc: 0.5141 - val_accuracy: 0.5080
#
# Epoch 00036: val_auc did not improve from 0.99998
# Epoch 37/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0297 - auc: 0.9985 - accuracy: 0.9917 - val_loss: 0.0055 - val_auc: 1.0000 - val_accuracy: 0.9980
#
# Epoch 00037: val_auc improved from 0.99998 to 0.99999, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5
# Epoch 38/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0017 - auc: 1.0000 - accuracy: 0.9998 - val_loss: 0.1443 - val_auc: 0.9908 - val_accuracy: 0.9720
#
# Epoch 00038: val_auc did not improve from 0.99999
# Epoch 39/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0142 - auc: 0.9991 - accuracy: 0.9970 - val_loss: 1.4054 - val_auc: 0.8553 - val_accuracy: 0.8260
#
# Epoch 00039: val_auc did not improve from 0.99999
# Epoch 40/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0080 - auc: 1.0000 - accuracy: 0.9969 - val_loss: 1.0451 - val_auc: 0.8491 - val_accuracy: 0.7520
#
# Epoch 00040: val_auc did not improve from 0.99999
# Epoch 41/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0147 - auc: 0.9992 - accuracy: 0.9943 - val_loss: 4.5145 - val_auc: 0.4980 - val_accuracy: 0.4960
#
# Epoch 00041: val_auc did not improve from 0.99999
# Epoch 42/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0213 - auc: 0.9995 - accuracy: 0.9914 - val_loss: 1.6685 - val_auc: 0.7062 - val_accuracy: 0.5960
#
# Epoch 00042: val_auc did not improve from 0.99999
# Epoch 43/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0270 - auc: 0.9996 - accuracy: 0.9903 - val_loss: 0.0061 - val_auc: 1.0000 - val_accuracy: 0.9980
#
# Epoch 00043: val_auc did not improve from 0.99999
# Epoch 44/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0161 - auc: 0.9998 - accuracy: 0.9973 - val_loss: 2.6026 - val_auc: 0.7894 - val_accuracy: 0.7600
#
# Epoch 00044: val_auc did not improve from 0.99999
# Epoch 45/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0118 - auc: 0.9991 - accuracy: 0.9971 - val_loss: 0.1130 - val_auc: 0.9942 - val_accuracy: 0.9620
#
# Epoch 00045: val_auc did not improve from 0.99999
# Epoch 46/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0135 - auc: 0.9999 - accuracy: 0.9964 - val_loss: 0.0129 - val_auc: 0.9980 - val_accuracy: 0.9980
#
# Epoch 00046: val_auc did not improve from 0.99999
# Epoch 47/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0099 - auc: 0.9999 - accuracy: 0.9975 - val_loss: 0.0133 - val_auc: 0.9999 - val_accuracy: 0.9960
#
# Epoch 00047: val_auc did not improve from 0.99999
# Epoch 48/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0492 - auc: 0.9968 - accuracy: 0.9868 - val_loss: 2.8042 - val_auc: 0.6631 - val_accuracy: 0.5920
#
# Epoch 00048: val_auc did not improve from 0.99999
# Epoch 49/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0249 - auc: 0.9991 - accuracy: 0.9913 - val_loss: 0.5819 - val_auc: 0.9255 - val_accuracy: 0.8380
#
# Epoch 00049: val_auc did not improve from 0.99999
# Epoch 50/50
# 52/52 [==============================] - 66s 1s/step - loss: 0.0181 - auc: 0.9996 - accuracy: 0.9912 - val_loss: 0.0104 - val_auc: 1.0000 - val_accuracy: 1.0000
#
# Epoch 00050: val_auc improved from 0.99999 to 0.99999, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5

# %%
sig128_model = load_model("/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_128.hdf5")

# %%
y_actual2 , y_test2 = [],[]
for i in os.listdir("/content/sign_data_mod_mod/test/GENUINE/"):
    img=image.load_img("/content/sign_data_mod_mod/test/GENUINE/"+i,target_size=(128,128),color_mode='grayscale')
    img2=image.img_to_array(img)
    img3=img2/255.0
    img4=np.expand_dims(img3,axis=0)
    pred=sig128_model.predict(img4)
    pred1 = np.argmax(pred,axis=-1)
    y_test2.append(pred1[0])
    y_actual2.append(1)
for i in os.listdir("/content/sign_data_mod_mod/test/FORGED/"):
    img=image.load_img("/content/sign_data_mod_mod/test/FORGED/"+i,target_size=(128,128),color_mode='grayscale')
    img2=image.img_to_array(img)
    img3=img2/255.0
    img4=np.expand_dims(img3,axis=0)
    pred=sig128_model.predict(img4)
    pred1 = np.argmax(pred,axis=-1)
    y_test2.append(pred1[0])
    y_actual2.append(0)
y_actual2=np.array(y_actual2)
y_test2=np.array(y_test2)

# %%
cn2=confusion_matrix(y_actual2,y_test2)
print(metrics.classification_report(y_actual2,y_test2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       248
#            1       1.00      1.00      1.00       252
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500

# %%
sns.heatmap(cn2,cmap="icefire",annot=True, fmt=".1f")

# %%
acc = sig128_hist.history['accuracy']
val_acc = sig128_hist.history['val_accuracy']

auc = sig128_hist.history['auc']
val_auc = sig128_hist.history['val_auc']
epochs_range = range(50)

plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, auc, label='Training auc')
plt.plot(epochs_range, val_auc, label='Validation auc')
plt.legend(loc='upper right')
plt.title('Training and Validation auc')
plt.show()

# %%
train_datagen = image.ImageDataGenerator(rescale = 1./255)
test_datagen = image.ImageDataGenerator(rescale= 1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (256,256),
    color_mode='grayscale',
    batch_size = 8,
    class_mode = "categorical"
    )
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (256,256),
    color_mode='grayscale',
    batch_size = 8,
    class_mode = "categorical"
    )
# Out:
# Found 1649 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'FORGED': 0, 'GENUINE': 1}

# %%
def Network256(input_shape, nb_class, depth):
  xin = Input(shape= input_shape)

  x = Conv2D(16, kernel_size = (5,5), strides= (1,1), padding = 'same', activation='relu')(xin)
  x = BatchNormalization()(x)

  x = Conv2D(32, kernel_size = (3,3), strides= (2,2), padding = 'same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=6, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=32, max_dilation=6)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=64, max_dilation=5, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=64, max_dilation=5)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=128, max_dilation=4, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=128, max_dilation=4)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=256, max_dilation=3, number_of_units=depth)
  x = Shifter_Unit(input_tensor=x, nb_of_input_channels=256, max_dilation=3)

  x = Residual_Unit(input_tensor=x, nb_of_input_channels=512, max_dilation=2, number_of_units=depth)

  x = GlobalAveragePooling2D()(x)

  x = Dense(64, activation='relu')(x)
  x = Dense(nb_class, activation= 'softmax')(x)

  model = Model(xin, x)

  model.compile(loss='categorical_crossentropy', optimizer = keras.optimizers.Adam(learning_rate=0.01), metrics = [tf.keras.metrics.AUC(),"accuracy"])

  return model

# %%
sig256_model = Network256(input_shape = (256, 256, 1), nb_class = 2 , depth = 5)
sig256_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 416         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 4640        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 64) 2112        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 128, 128, 64) 640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 64) 256         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 64) 256         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 64) 256         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 64) 256         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 64) 256         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 128, 384 0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 12320       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 32) 0           batch_normalization_9[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 2112        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 384 0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
#                                                                  batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 32) 12320       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 32) 0           batch_normalization_17[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 64) 2112        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 64) 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 384 0           batch_normalization_19[0][0]
#                                                                  batch_normalization_20[0][0]
#                                                                  batch_normalization_21[0][0]
#                                                                  batch_normalization_22[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 32) 12320       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 128, 128, 32) 128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 128, 32) 0           batch_normalization_25[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 64) 2112        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 128, 128, 64) 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_18 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_19 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_21 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_22 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 384 0           batch_normalization_27[0][0]
#                                                                  batch_normalization_28[0][0]
#                                                                  batch_normalization_29[0][0]
#                                                                  batch_normalization_30[0][0]
#                                                                  batch_normalization_31[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 32) 12320       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 128, 128, 32) 128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 32) 0           batch_normalization_33[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 64) 2112        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 128, 128, 64) 256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_25 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_26 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_27 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_28 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_29 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 128, 128, 64) 256         depthwise_conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 384 0           batch_normalization_35[0][0]
#                                                                  batch_normalization_36[0][0]
#                                                                  batch_normalization_37[0][0]
#                                                                  batch_normalization_38[0][0]
#                                                                  batch_normalization_39[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 32) 12320       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 128, 128, 32) 128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 32) 0           batch_normalization_41[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 128 4224        add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 128, 128, 128 512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_30 (DepthwiseC (None, 128, 128, 128 1280        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_31 (DepthwiseC (None, 128, 128, 128 1280        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_32 (DepthwiseC (None, 128, 128, 128 1280        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_33 (DepthwiseC (None, 128, 128, 128 1280        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_34 (DepthwiseC (None, 128, 128, 128 1280        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_35 (DepthwiseC (None, 128, 128, 128 1280        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 128)  0           depthwise_conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           depthwise_conv2d_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           depthwise_conv2d_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 128)  0           depthwise_conv2d_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 128)  0           depthwise_conv2d_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 128)  0           depthwise_conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 64, 64, 128)  512         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 64, 64, 128)  512         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 64, 64, 128)  512         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 64, 64, 128)  512         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 64, 64, 128)  512         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 64, 64, 128)  512         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 768)  0           batch_normalization_43[0][0]
#                                                                  batch_normalization_44[0][0]
#                                                                  batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
#                                                                  batch_normalization_47[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 64)   49216       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 64, 64, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 128)  8320        batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 64, 64, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_36 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_37 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_38 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_39 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_40 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 640)  0           batch_normalization_51[0][0]
#                                                                  batch_normalization_52[0][0]
#                                                                  batch_normalization_53[0][0]
#                                                                  batch_normalization_54[0][0]
#                                                                  batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   41024       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 64, 64, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 64)   0           batch_normalization_56[0][0]
#                                                                  batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 128)  8320        add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 64, 64, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_41 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_42 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_43 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_44 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_45 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 640)  0           batch_normalization_58[0][0]
#                                                                  batch_normalization_59[0][0]
#                                                                  batch_normalization_60[0][0]
#                                                                  batch_normalization_61[0][0]
#                                                                  batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 64)   41024       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 64, 64, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 64)   0           batch_normalization_63[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 128)  8320        add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 64, 64, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_46 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_47 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_48 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_49 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_50 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 64, 64, 640)  0           batch_normalization_65[0][0]
#                                                                  batch_normalization_66[0][0]
#                                                                  batch_normalization_67[0][0]
#                                                                  batch_normalization_68[0][0]
#                                                                  batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 64)   41024       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 64, 64, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 64)   0           batch_normalization_70[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 128)  8320        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 64, 64, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_51 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_52 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_53 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_54 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_55 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_55[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 64, 64, 640)  0           batch_normalization_72[0][0]
#                                                                  batch_normalization_73[0][0]
#                                                                  batch_normalization_74[0][0]
#                                                                  batch_normalization_75[0][0]
#                                                                  batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   41024       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 64, 64, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 64)   0           batch_normalization_77[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 128)  8320        add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 64, 64, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_56 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_57 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_58 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_59 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_60 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 64, 64, 128)  512         depthwise_conv2d_60[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 64, 64, 640)  0           batch_normalization_79[0][0]
#                                                                  batch_normalization_80[0][0]
#                                                                  batch_normalization_81[0][0]
#                                                                  batch_normalization_82[0][0]
#                                                                  batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 64)   41024       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 64, 64, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 64)   0           batch_normalization_84[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 256)  16640       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 64, 64, 256)  1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_61 (DepthwiseC (None, 64, 64, 256)  2560        batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_62 (DepthwiseC (None, 64, 64, 256)  2560        batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_63 (DepthwiseC (None, 64, 64, 256)  2560        batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_64 (DepthwiseC (None, 64, 64, 256)  2560        batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_65 (DepthwiseC (None, 64, 64, 256)  2560        batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 256)  0           depthwise_conv2d_61[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 256)  0           depthwise_conv2d_62[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 256)  0           depthwise_conv2d_63[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 256)  0           depthwise_conv2d_64[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 256)  0           depthwise_conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 32, 32, 256)  1024        max_pooling2d_6[0][0]
# ...
# batch_normalization_151 (BatchN (None, 16, 16, 512)  2048        depthwise_conv2d_104[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 16, 16, 1536) 0           batch_normalization_149[0][0]
#                                                                  batch_normalization_150[0][0]
#                                                                  batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 256)  393472      concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 16, 16, 256)  1024        conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 16, 16, 256)  0           batch_normalization_152[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 1024) 263168      add_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 16, 16, 1024) 4096        conv2d_48[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_105 (Depthwise (None, 16, 16, 1024) 10240       batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_106 (Depthwise (None, 16, 16, 1024) 10240       batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_107 (Depthwise (None, 16, 16, 1024) 10240       batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 8, 8, 1024)   0           depthwise_conv2d_105[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 1024)   0           depthwise_conv2d_106[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 8, 8, 1024)   0           depthwise_conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 8, 8, 1024)   4096        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 8, 8, 1024)   4096        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 8, 8, 1024)   4096        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 8, 8, 3072)   0           batch_normalization_154[0][0]
#                                                                  batch_normalization_155[0][0]
#                                                                  batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 512)    1573376     concatenate_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 8, 8, 512)    2048        conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 1024)   525312      batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 8, 8, 1024)   4096        conv2d_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_108 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_109 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_109[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 8, 8, 2048)   0           batch_normalization_159[0][0]
#                                                                  batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 512)    1049088     concatenate_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 8, 8, 512)    2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 8, 8, 512)    0           batch_normalization_161[0][0]
#                                                                  batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 1024)   525312      add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 8, 8, 1024)   4096        conv2d_52[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_110 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_111 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_111[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 8, 8, 2048)   0           batch_normalization_163[0][0]
#                                                                  batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 512)    1049088     concatenate_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 8, 8, 512)    2048        conv2d_53[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 8, 8, 512)    0           batch_normalization_165[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 1024)   525312      add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 8, 8, 1024)   4096        conv2d_54[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_112 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_113 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_113[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 8, 8, 2048)   0           batch_normalization_167[0][0]
#                                                                  batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 512)    1049088     concatenate_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 8, 8, 512)    2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 8, 8, 512)    0           batch_normalization_169[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 1024)   525312      add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 8, 8, 1024)   4096        conv2d_56[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_114 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_115 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_115[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 8, 8, 2048)   0           batch_normalization_171[0][0]
#                                                                  batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 512)    1049088     concatenate_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 8, 8, 512)    2048        conv2d_57[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 8, 8, 512)    0           batch_normalization_173[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 1024)   525312      add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 8, 8, 1024)   4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_116 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_117 (Depthwise (None, 8, 8, 1024)   10240       batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 8, 8, 1024)   4096        depthwise_conv2d_117[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 8, 8, 2048)   0           batch_normalization_175[0][0]
#                                                                  batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 8, 8, 512)    1049088     concatenate_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 8, 8, 512)    2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 8, 8, 512)    0           batch_normalization_177[0][0]
#                                                                  add_23[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           add_24[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           32832       global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            130         dense[0][0]
# ==================================================================================================
# Total params: 14,902,306
# Trainable params: 14,796,034
# Non-trainable params: 106,272
# __________________________________________________________________________________________________

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_256.hdf5",
    monitor='val_auc',
    verbose = 1,
    mode='max',
    save_best_only=True)

# %%
sig256_hist = sig256_model.fit(x=train_generator,
                              validation_data=test_generator,
                              epochs = 50,
                              callbacks=[model_checkpoint_callback]
                              )
# Out:
# Epoch 1/50
# 207/207 [==============================] - 395s 2s/step - loss: 1.6836 - auc: 0.7407 - accuracy: 0.6984 - val_loss: 0.9015 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00001: val_auc improved from -inf to 0.50400, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_256.hdf5
# Epoch 2/50
# 207/207 [==============================] - 340s 2s/step - loss: 0.4348 - auc: 0.8920 - accuracy: 0.8132 - val_loss: 3.0554 - val_auc: 0.3952 - val_accuracy: 0.5040
#
# Epoch 00002: val_auc did not improve from 0.50400
# Epoch 3/50
# 207/207 [==============================] - 340s 2s/step - loss: 0.3232 - auc: 0.9391 - accuracy: 0.8665 - val_loss: 0.7848 - val_auc: 0.4929 - val_accuracy: 0.5220
#
# Epoch 00003: val_auc did not improve from 0.50400
# Epoch 4/50
# 207/207 [==============================] - 339s 2s/step - loss: 0.3574 - auc: 0.9255 - accuracy: 0.8665 - val_loss: 0.2163 - val_auc: 0.9853 - val_accuracy: 0.9640
#
# Epoch 00004: val_auc improved from 0.50400 to 0.98527, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_256.hdf5
# Epoch 5/50
# 207/207 [==============================] - 340s 2s/step - loss: 0.3317 - auc: 0.9413 - accuracy: 0.8857 - val_loss: 0.1670 - val_auc: 0.9825 - val_accuracy: 0.9460
#
# Epoch 00005: val_auc did not improve from 0.98527
# Epoch 6/50
# 207/207 [==============================] - 339s 2s/step - loss: 0.2169 - auc: 0.9711 - accuracy: 0.9252 - val_loss: 5.9033 - val_auc: 0.7542 - val_accuracy: 0.7280
#
# Epoch 00006: val_auc did not improve from 0.98527
# Epoch 7/50
# 207/207 [==============================] - 339s 2s/step - loss: 0.2369 - auc: 0.9650 - accuracy: 0.9155 - val_loss: 0.0923 - val_auc: 0.9937 - val_accuracy: 0.9560
#
# Epoch 00007: val_auc improved from 0.98527 to 0.99369, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_256.hdf5
# Epoch 8/50
# 207/207 [==============================] - 340s 2s/step - loss: 0.1981 - auc: 0.9756 - accuracy: 0.9331 - val_loss: 1.2045 - val_auc: 0.8056 - val_accuracy: 0.6660
#
# Epoch 00008: val_auc did not improve from 0.99369
# Epoch 9/50
# 207/207 [==============================] - 340s 2s/step - loss: 0.2363 - auc: 0.9665 - accuracy: 0.9213 - val_loss: 0.0535 - val_auc: 0.9966 - val_accuracy: 0.9800
#
# Epoch 00009: val_auc improved from 0.99369 to 0.99658, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_256.hdf5
# Epoch 10/50
# 207/207 [==============================] - 339s 2s/step - loss: 0.2890 - auc: 0.9566 - accuracy: 0.9050 - val_loss: 0.7865 - val_auc: 0.8302 - val_accuracy: 0.7120
#
# Epoch 00010: val_auc did not improve from 0.99658
# Epoch 11/50
# 207/207 [==============================] - 340s 2s/step - loss: 0.2143 - auc: 0.9752 - accuracy: 0.9275 - val_loss: 1.3736 - val_auc: 0.7679 - val_accuracy: 0.6680
#
# Epoch 00011: val_auc did not improve from 0.99658
# Epoch 12/50
# 207/207 [==============================] - 340s 2s/step - loss: 0.1990 - auc: 0.9767 - accuracy: 0.9388 - val_loss: 0.2013 - val_auc: 0.9759 - val_accuracy: 0.8880
#
# Epoch 00012: val_auc did not improve from 0.99658
# Epoch 13/50
# 207/207 [==============================] - 340s 2s/step - loss: 0.2387 - auc: 0.9699 - accuracy: 0.9091 - val_loss: 0.0700 - val_auc: 0.9977 - val_accuracy: 0.9760
#
# Epoch 00013: val_auc improved from 0.99658 to 0.99769, saving model to /content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_256.hdf5
# Epoch 14/50
# 207/207 [==============================] - 340s 2s/step - loss: 0.2420 - auc: 0.9661 - accuracy: 0.9030 - val_loss: 52.9576 - val_auc: 0.4960 - val_accuracy: 0.4960
#
# Epoch 00014: val_auc did not improve from 0.99769
# Epoch 15/50
# 207/207 [==============================] - 339s 2s/step - loss: 0.5891 - auc: 0.8793 - accuracy: 0.8241 - val_loss: 0.8143 - val_auc: 0.8088 - val_accuracy: 0.6400
#
# Epoch 00015: val_auc did not improve from 0.99769
# Epoch 16/50
# 207/207 [==============================] - 333s 2s/step - loss: 0.6191 - auc: 0.7423 - accuracy: 0.6912 - val_loss: 0.6936 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00016: val_auc did not improve from 0.99769
# Epoch 17/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6923 - auc: 0.5147 - accuracy: 0.5293 - val_loss: 0.6938 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00017: val_auc did not improve from 0.99769
# Epoch 18/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6902 - auc: 0.5363 - accuracy: 0.5428 - val_loss: 0.6933 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00018: val_auc did not improve from 0.99769
# Epoch 19/50
# 207/207 [==============================] - 331s 2s/step - loss: 0.6911 - auc: 0.5239 - accuracy: 0.5483 - val_loss: 0.6956 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00019: val_auc did not improve from 0.99769
# Epoch 20/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6924 - auc: 0.5138 - accuracy: 0.5316 - val_loss: 0.6952 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00020: val_auc did not improve from 0.99769
# Epoch 21/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6921 - auc: 0.5258 - accuracy: 0.5309 - val_loss: 0.7001 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00021: val_auc did not improve from 0.99769
# Epoch 22/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6872 - auc: 0.5401 - accuracy: 0.5573 - val_loss: 0.6934 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00022: val_auc did not improve from 0.99769
# Epoch 23/50
# 207/207 [==============================] - 333s 2s/step - loss: 0.6914 - auc: 0.5229 - accuracy: 0.5377 - val_loss: 0.6948 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00023: val_auc did not improve from 0.99769
# Epoch 24/50
# 207/207 [==============================] - 331s 2s/step - loss: 0.6903 - auc: 0.5313 - accuracy: 0.5409 - val_loss: 0.6942 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00024: val_auc did not improve from 0.99769
# Epoch 25/50
# 207/207 [==============================] - 331s 2s/step - loss: 0.6911 - auc: 0.5267 - accuracy: 0.5403 - val_loss: 0.6944 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00025: val_auc did not improve from 0.99769
# Epoch 26/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6918 - auc: 0.5223 - accuracy: 0.5317 - val_loss: 0.6960 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00026: val_auc did not improve from 0.99769
# Epoch 27/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6904 - auc: 0.5264 - accuracy: 0.5438 - val_loss: 0.6949 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00027: val_auc did not improve from 0.99769
# Epoch 28/50
# 207/207 [==============================] - 333s 2s/step - loss: 0.6925 - auc: 0.5196 - accuracy: 0.5235 - val_loss: 0.6983 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00028: val_auc did not improve from 0.99769
# Epoch 29/50
# 207/207 [==============================] - 331s 2s/step - loss: 0.6939 - auc: 0.5142 - accuracy: 0.5229 - val_loss: 0.7023 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00029: val_auc did not improve from 0.99769
# Epoch 30/50
# 207/207 [==============================] - 334s 2s/step - loss: 0.6931 - auc: 0.5221 - accuracy: 0.5315 - val_loss: 0.6945 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00030: val_auc did not improve from 0.99769
# Epoch 31/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6899 - auc: 0.5342 - accuracy: 0.5470 - val_loss: 0.6979 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00031: val_auc did not improve from 0.99769
# Epoch 32/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6865 - auc: 0.5526 - accuracy: 0.5599 - val_loss: 0.6934 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00032: val_auc did not improve from 0.99769
# Epoch 33/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6915 - auc: 0.5277 - accuracy: 0.5349 - val_loss: 0.6945 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00033: val_auc did not improve from 0.99769
# Epoch 34/50
# 207/207 [==============================] - 333s 2s/step - loss: 0.6915 - auc: 0.5207 - accuracy: 0.5347 - val_loss: 0.6946 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00034: val_auc did not improve from 0.99769
# Epoch 35/50
# 207/207 [==============================] - 331s 2s/step - loss: 0.6940 - auc: 0.4959 - accuracy: 0.5042 - val_loss: 0.7050 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00035: val_auc did not improve from 0.99769
# Epoch 36/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6845 - auc: 0.5588 - accuracy: 0.5633 - val_loss: 0.6939 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00036: val_auc did not improve from 0.99769
# Epoch 37/50
# 207/207 [==============================] - 331s 2s/step - loss: 0.6915 - auc: 0.5179 - accuracy: 0.5379 - val_loss: 0.6940 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00037: val_auc did not improve from 0.99769
# Epoch 38/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6929 - auc: 0.5135 - accuracy: 0.5295 - val_loss: 0.6962 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00038: val_auc did not improve from 0.99769
# Epoch 39/50
# 207/207 [==============================] - 333s 2s/step - loss: 0.6906 - auc: 0.5367 - accuracy: 0.5373 - val_loss: 0.7035 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00039: val_auc did not improve from 0.99769
# Epoch 40/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6938 - auc: 0.5207 - accuracy: 0.5307 - val_loss: 0.6960 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00040: val_auc did not improve from 0.99769
# Epoch 41/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6862 - auc: 0.5624 - accuracy: 0.5610 - val_loss: 0.6931 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00041: val_auc did not improve from 0.99769
# Epoch 42/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6927 - auc: 0.5107 - accuracy: 0.5178 - val_loss: 0.6974 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00042: val_auc did not improve from 0.99769
# Epoch 43/50
# 207/207 [==============================] - 331s 2s/step - loss: 0.6927 - auc: 0.5194 - accuracy: 0.5316 - val_loss: 0.6969 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00043: val_auc did not improve from 0.99769
# Epoch 44/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6940 - auc: 0.5094 - accuracy: 0.5191 - val_loss: 0.6966 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00044: val_auc did not improve from 0.99769
# Epoch 45/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6950 - auc: 0.4989 - accuracy: 0.5186 - val_loss: 0.6969 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00045: val_auc did not improve from 0.99769
# Epoch 46/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6918 - auc: 0.5169 - accuracy: 0.5338 - val_loss: 0.6960 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00046: val_auc did not improve from 0.99769
# Epoch 47/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6888 - auc: 0.5462 - accuracy: 0.5513 - val_loss: 0.6939 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00047: val_auc did not improve from 0.99769
# Epoch 48/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6894 - auc: 0.5324 - accuracy: 0.5538 - val_loss: 0.6933 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00048: val_auc did not improve from 0.99769
# Epoch 49/50
# 207/207 [==============================] - 331s 2s/step - loss: 0.6929 - auc: 0.5019 - accuracy: 0.5251 - val_loss: 0.6989 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00049: val_auc did not improve from 0.99769
# Epoch 50/50
# 207/207 [==============================] - 332s 2s/step - loss: 0.6905 - auc: 0.5313 - accuracy: 0.5402 - val_loss: 0.6958 - val_auc: 0.5040 - val_accuracy: 0.5040
#
# Epoch 00050: val_auc did not improve from 0.99769

# %%
sig256_model = load_model("/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/best_model_256.hdf5")

# %%
y_actual2 , y_test2 = [],[]
for i in os.listdir("/content/sign_data_mod_mod/test/GENUINE/"):
    img=image.load_img("/content/sign_data_mod_mod/test/GENUINE/"+i,target_size=(256,256),color_mode='grayscale')
    img2=image.img_to_array(img)
    img3=img2/255.0
    img4=np.expand_dims(img3,axis=0)
    pred=sig256_model.predict(img4)
    pred1 = np.argmax(pred,axis=-1)
    y_test2.append(pred1[0])
    y_actual2.append(1)
for i in os.listdir("/content/sign_data_mod_mod/test/FORGED/"):
    img=image.load_img("/content/sign_data_mod_mod/test/FORGED/"+i,target_size=(256,256),color_mode='grayscale')
    img2=image.img_to_array(img)
    img3=img2/255.0
    img4=np.expand_dims(img3,axis=0)
    pred=sig256_model.predict(img4)
    pred1 = np.argmax(pred,axis=-1)
    y_test2.append(pred1[0])
    y_actual2.append(0)
y_actual2=np.array(y_actual2)
y_test2=np.array(y_test2)

# %%
cn2=confusion_matrix(y_actual2,y_test2)
print(metrics.classification_report(y_actual2,y_test2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98       248
#            1       0.95      1.00      0.98       252
#
#     accuracy                           0.98       500
#    macro avg       0.98      0.98      0.98       500
# weighted avg       0.98      0.98      0.98       500

# %%
sns.heatmap(cn2,cmap="icefire",annot=True)

# %%
acc = sig256_hist.history['accuracy']
val_acc = sig256_hist.history['val_accuracy']

auc = sig256_hist.history['auc']
val_auc = sig256_hist.history['val_auc']
epochs_range = range(50)

plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, auc, label='Training auc')
plt.plot(epochs_range, val_auc, label='Validation auc')
plt.legend(loc='upper right')
plt.title('Training and Validation auc')
plt.show()
