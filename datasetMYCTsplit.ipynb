# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/MCYT_sig_pics.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: MCYT_sig_pics/0001/0001v23.png
#   inflating: MCYT_sig_pics/0001/0001v24.png
#    creating: MCYT_sig_pics/0002/
#   inflating: MCYT_sig_pics/0002/0002f00.png
#   inflating: MCYT_sig_pics/0002/0002f01.png
#   inflating: MCYT_sig_pics/0002/0002f02.png
#   inflating: MCYT_sig_pics/0002/0002f03.png
#   inflating: MCYT_sig_pics/0002/0002f04.png
#   inflating: MCYT_sig_pics/0002/0002f05.png
#   inflating: MCYT_sig_pics/0002/0002f06.png
#   inflating: MCYT_sig_pics/0002/0002f07.png
#   inflating: MCYT_sig_pics/0002/0002f08.png
#   inflating: MCYT_sig_pics/0002/0002f09.png
#   inflating: MCYT_sig_pics/0002/0002f10.png
#   inflating: MCYT_sig_pics/0002/0002f11.png
#   inflating: MCYT_sig_pics/0002/0002f12.png
#   inflating: MCYT_sig_pics/0002/0002f13.png
#   inflating: MCYT_sig_pics/0002/0002f14.png
#   inflating: MCYT_sig_pics/0002/0002f15.png
#   inflating: MCYT_sig_pics/0002/0002f16.png
# ...

# %%
import os 
import shutil

# %%
for root, dirs, files in os.walk("/content/MCYT_sig_pics"):
  for dir in dirs:
    #print(os.listdir(os.path.join(root, dir)))
    fol = sorted(os.listdir(os.path.join(root, dir)))
    for i,fp in enumerate(fol):
      filepath = os.path.join(root,dir,fp)
      #print(filepath)
      if i<12:
        shutil.move(filepath, os.path.join("/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/MYCT_pics_updated/train/forged",fp))
        continue
      elif i<24:
        shutil.move(filepath, os.path.join("/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/MYCT_pics_updated/test/forged",fp))
        continue
      elif i<25:
        shutil.move(filepath, os.path.join("/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/MYCT_pics_updated/val/forged",fp))
        continue
      elif i<37:
        shutil.move(filepath, os.path.join("/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/MYCT_pics_updated/train/genuine",fp))
        continue
      elif i<49:
        shutil.move(filepath, os.path.join("/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/MYCT_pics_updated/test/genuine",fp))
        continue
      elif i<50:
        shutil.move(filepath, os.path.join("/content/drive/MyDrive/Tanweer Internships & Jobs/Rashmi Sir/MYCT_pics_updated/val/genuine",fp))
        continue
